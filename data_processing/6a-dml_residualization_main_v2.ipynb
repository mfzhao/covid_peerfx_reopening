# %%
library(readr)
library(dplyr)
library(tidyr)
library(stringr)
library(doMC)
library(lfe)
library(xgboost)
registerDoMC(24)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: foreach
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
#
# Attaching package: ‘xgboost’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     slice

# %%
fp <- '/pool001/mfzhao/'
df <- read_rds(str_c(fp, 'PROCESSED_DATA/panel_pre_xgr.RDS'))

# %%
df %>%
    arrange(key, date) %>%
    group_by(key) %>%
    mutate_at(vars(p1sdp, p2shp, p3rop, stalter_p1sdp, stalter_p2shp, stalter_p3rop),
              .funs = list(l01 = function(x) lag(x),
                           l02 = function(x) lag(x, 2),
                           l03 = function(x) lag(x, 3),
                           l04 = function(x) lag(x, 4),
                           l05 = function(x) lag(x, 5),
                           l06 = function(x) lag(x, 6),
                           l07 = function(x) lag(x, 7),
                           l08 = function(x) lag(x, 8),
                           l09 = function(x) lag(x, 9),
                           l10 = function(x) lag(x, 10),
                           m01 = function(x) lead(x),
                           m02 = function(x) lead(x, 2),
                           m03 = function(x) lead(x, 3),
                           m04 = function(x) lead(x, 4),
                           m05 = function(x) lead(x, 5),
                           m06 = function(x) lead(x, 6),
                           m07 = function(x) lead(x, 7),
                           m08 = function(x) lead(x, 8),
                           m09 = function(x) lead(x, 9),
                           m10 = function(x) lead(x, 10))) -> df

df %>%
    fill(matches("m[01][0-9]"), .direction = 'down') %>%
    fill(matches("l[01][0-9]"), .direction = 'up') -> df

# %%
set.seed(2345)
df %>%
    ungroup() %>%
    select(key) %>%
    distinct() %>% 
    mutate(i = sample(1:n(), n(), replace = F),
           fold = i %% 3 + 1) %>%
    select(-i) -> folds

df %>%
    inner_join(folds) %>%
    arrange(date, key) %>%
    ungroup() -> df

df %>%
    ungroup() %>%
    mutate(PRCP.r_fe      = felm(PRCP ~ 0 | key + date, ., weights = df$n)$resid,
           TMAX.r_fe      = felm(TMAX ~ 0 | key + date, ., weights = df$n)$resid,
           newcases.r_fe  = felm(newcases ~ 0 | key + date, ., weights = df$n)$resid,
           newdeaths.r_fe = felm(newdeaths ~ 0 | key + date, ., weights = df$n)$resid) %>%
    select(date, key, PRCP.r_fe, TMAX.r_fe, newcases.r_fe, newdeaths.r_fe, fold, n) -> residualizer_df

folds <- list(which(folds$fold %in% 1), 
              which(folds$fold %in% 2), 
              which(folds$fold %in% 3))

write_rds(folds, str_c(fp, 'PROCESSED_DATA/folds.RDS'))
write_rds(residualizer_df, str_c(fp, 'PROCESSED_DATA/residualizer_data.RDS'))
# Out:
# Joining, by = "key"

# %%
XGresidualizer <- function(Y, colname) {
    print(colname)
    residualizer_df %>%
        ungroup() %>% 
        mutate(Y = Y,
               Y.r = felm(Y ~ 0 | key + date, ., weights = residualizer_df$n)$resid) -> temp_df
  
    folds <- list(which(temp_df$fold %in% 1), 
                  which(temp_df$fold %in% 2), 
                  which(temp_df$fold %in% 3))
    
    X     <- model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe + newcases.r_fe + newdeaths.r_fe, temp_df)
    dm    <- xgb.DMatrix(data = X, label = temp_df$Y.r)
    param <- list(max_depth=2, eta=.5, silent=1, objective='reg:linear')
    fit   <- xgb.cv(params = param, 
                    data = dm, 
                    folds = folds,
                    nrounds = 100, 
                    early_stopping_rounds = 3, 
                    weight = temp_df$n)
    best_n <- fit$best_iteration
    for (i in 1:3) {
        tr  <- temp_df %>% filter(fold != i)
        trm <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe + newcases.r_fe + newdeaths.r_fe, tr), label = tr$Y.r)
        fit <- xgb.train(params = param, 
                         data = trm, 
                         nrounds = best_n, 
                         weight = tr$n)
        te  <- temp_df %>% filter(fold == i)
        tem <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe + newcases.r_fe + newdeaths.r_fe, te), label = te$Y.r)
        te %>%
            select(date, key) %>%
            mutate(pred = predict(fit, newdata = tem)) -> pred_df
        assign(str_c('temp',i), pred_df) %>%
        select(-pred, -date, -key)
    }
    out <- bind_rows(temp1, temp2, temp3) %>%
        arrange(date, key) %>%
        mutate(tempname = temp_df$Y.r - pred) %>%
        select(-pred, -date, -key)
    
    colnames(out) <- str_c(colname, '.r')
    return(out)
}

# %%
cols_to_xgr <- colnames(
    df %>%
        select(
            -cases,
            -newcases,
            -deaths,
            -newdeaths,
            -matches('^d'),
            -matches('^pc'),
            -matches('alter_d'),
            -matches('alter_pc'),
            -matches('log_d'),
            -matches('log_pc'),
            -date,
            -key,
            -cluster,
            -n,
            -fold,
            -matches('PRCP', ignore.case = F),
            -matches('TMAX', ignore.case = F),
            -matches('^prcp..'),
            -matches('^tmax..')
         )
)
cols_to_xgr
# Out:
#   [1] "mcbgv"                "pnchd"                "pgt1hafh"
#   [4] "ppthlt75"             "pgt2kmt"              "p1sdp"
#   [7] "p2shp"                "p3rop"                "p1sdpDSS"
#  [10] "p2shpDSS"             "p3ropDSS"             "stalter_mcbgv"
#  [13] "stalter_pnchd"        "stalter_pgt1hafh"     "stalter_ppthlt75"
#  [16] "stalter_pgt2kmt"      "stalter_p1sdp"        "stalter_p2shp"
#  [19] "stalter_p3rop"        "stalter_p1sdpDSS"     "stalter_p2shpDSS"
#  [22] "stalter_p3ropDSS"     "stalter_prcp01"       "stalter_prcp02"
#  [25] "stalter_prcp03"       "stalter_prcp04"       "stalter_prcp05"
#  [28] "stalter_prcp06"       "stalter_prcp07"       "stalter_prcp08"
#  [31] "stalter_prcp09"       "stalter_prcp10"       "stalter_tmax02"
#  [34] "stalter_tmax03"       "stalter_tmax04"       "stalter_tmax05"
#  [37] "stalter_tmax06"       "stalter_tmax07"       "stalter_tmax08"
#  [40] "stalter_tmax09"       "stalter_tmax10"       "alter_mcbgv"
#  [43] "alter_pnchd"          "alter_pgt1hafh"       "alter_ppthlt75"
#  [46] "alter_pgt2kmt"        "alter_p1sdp"          "alter_p2shp"
#  [49] "alter_p3rop"          "alter_p1sdpDSS"       "alter_p2shpDSS"
#  [52] "alter_p3ropDSS"       "alter_prcp01"         "alter_prcp02"
#  [55] "alter_prcp03"         "alter_prcp04"         "alter_prcp05"
#  [58] "alter_prcp06"         "alter_prcp07"         "alter_prcp08"
#  [61] "alter_prcp09"         "alter_prcp10"         "alter_tmax02"
#  [64] "alter_tmax03"         "alter_tmax04"         "alter_tmax05"
#  [67] "alter_tmax06"         "alter_tmax07"         "alter_tmax08"
#  [70] "alter_tmax09"         "alter_tmax10"         "log_mcbgv"
#  [73] "log_pnchd"            "log_pgt1hafh"         "log_ppthlt75"
#  [76] "log_pgt2kmt"          "log_stalter_mcbgv"    "log_stalter_pnchd"
#  [79] "log_stalter_pgt1hafh" "log_stalter_ppthlt75" "log_stalter_pgt2kmt"
#  [82] "log_alter_mcbgv"      "log_alter_pnchd"      "log_alter_pgt1hafh"
#  [85] "log_alter_ppthlt75"   "log_alter_pgt2kmt"    "p1sdp_l01"
#  [88] "p2shp_l01"            "p3rop_l01"            "stalter_p1sdp_l01"
#  [91] "stalter_p2shp_l01"    "stalter_p3rop_l01"    "p1sdp_l02"
#  [94] "p2shp_l02"            "p3rop_l02"            "stalter_p1sdp_l02"
#  [97] "stalter_p2shp_l02"    "stalter_p3rop_l02"    "p1sdp_l03"
# [100] "p2shp_l03"            "p3rop_l03"            "stalter_p1sdp_l03"
# [103] "stalter_p2shp_l03"    "stalter_p3rop_l03"    "p1sdp_l04"
# [106] "p2shp_l04"            "p3rop_l04"            "stalter_p1sdp_l04"
# [109] "stalter_p2shp_l04"    "stalter_p3rop_l04"    "p1sdp_l05"
# [112] "p2shp_l05"            "p3rop_l05"            "stalter_p1sdp_l05"
# [115] "stalter_p2shp_l05"    "stalter_p3rop_l05"    "p1sdp_l06"
# [118] "p2shp_l06"            "p3rop_l06"            "stalter_p1sdp_l06"
# [121] "stalter_p2shp_l06"    "stalter_p3rop_l06"    "p1sdp_l07"
# [124] "p2shp_l07"            "p3rop_l07"            "stalter_p1sdp_l07"
# [127] "stalter_p2shp_l07"    "stalter_p3rop_l07"    "p1sdp_l08"
# [130] "p2shp_l08"            "p3rop_l08"            "stalter_p1sdp_l08"
# [133] "stalter_p2shp_l08"    "stalter_p3rop_l08"    "p1sdp_l09"
# [136] "p2shp_l09"            "p3rop_l09"            "stalter_p1sdp_l09"
# [139] "stalter_p2shp_l09"    "stalter_p3rop_l09"    "p1sdp_l10"
# [142] "p2shp_l10"            "p3rop_l10"            "stalter_p1sdp_l10"
# [145] "stalter_p2shp_l10"    "stalter_p3rop_l10"    "p1sdp_m01"
# [148] "p2shp_m01"            "p3rop_m01"            "stalter_p1sdp_m01"
# [151] "stalter_p2shp_m01"    "stalter_p3rop_m01"    "p1sdp_m02"
# [154] "p2shp_m02"            "p3rop_m02"            "stalter_p1sdp_m02"
# [157] "stalter_p2shp_m02"    "stalter_p3rop_m02"    "p1sdp_m03"
# [160] "p2shp_m03"            "p3rop_m03"            "stalter_p1sdp_m03"
# [163] "stalter_p2shp_m03"    "stalter_p3rop_m03"    "p1sdp_m04"
# [166] "p2shp_m04"            "p3rop_m04"            "stalter_p1sdp_m04"
# [169] "stalter_p2shp_m04"    "stalter_p3rop_m04"    "p1sdp_m05"
# [172] "p2shp_m05"            "p3rop_m05"            "stalter_p1sdp_m05"
# [175] "stalter_p2shp_m05"    "stalter_p3rop_m05"    "p1sdp_m06"
# [178] "p2shp_m06"            "p3rop_m06"            "stalter_p1sdp_m06"
# [181] "stalter_p2shp_m06"    "stalter_p3rop_m06"    "p1sdp_m07"
# [184] "p2shp_m07"            "p3rop_m07"            "stalter_p1sdp_m07"
# [187] "stalter_p2shp_m07"    "stalter_p3rop_m07"    "p1sdp_m08"
# [190] "p2shp_m08"            "p3rop_m08"            "stalter_p1sdp_m08"
# [193] "stalter_p2shp_m08"    "stalter_p3rop_m08"    "p1sdp_m09"
# [196] "p2shp_m09"            "p3rop_m09"            "stalter_p1sdp_m09"
# [199] "stalter_p2shp_m09"    "stalter_p3rop_m09"    "p1sdp_m10"
# [202] "p2shp_m10"            "p3rop_m10"            "stalter_p1sdp_m10"
# [205] "stalter_p2shp_m10"    "stalter_p3rop_m10"

# %%
xg.residuals <- foreach(i = 1:length(cols_to_xgr), .combine = cbind) %do% XGresidualizer(df[[cols_to_xgr[i]]], cols_to_xgr[i])
# Out:
# [1] "mcbgv"
# [1]	train-rmse:0.272738+0.000164	test-rmse:0.272762+0.000216
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.161485+0.000273	test-rmse:0.161605+0.000155
# [3]	train-rmse:0.117707+0.000456	test-rmse:0.117877+0.000199
# [4]	train-rmse:0.103434+0.000494	test-rmse:0.103681+0.000427
# [5]	train-rmse:0.099211+0.000449	test-rmse:0.099481+0.000659
# [6]	train-rmse:0.097933+0.000446	test-rmse:0.098217+0.000739
# [7]	train-rmse:0.097403+0.000417	test-rmse:0.097705+0.000813
# [8]	train-rmse:0.097120+0.000397	test-rmse:0.097439+0.000861
# [9]	train-rmse:0.096925+0.000366	test-rmse:0.097249+0.000910
# [10]	train-rmse:0.096795+0.000380	test-rmse:0.097120+0.000898
# [11]	train-rmse:0.096657+0.000395	test-rmse:0.097018+0.000861
# [12]	train-rmse:0.096559+0.000424	test-rmse:0.096966+0.000845
# [13]	train-rmse:0.096486+0.000432	test-rmse:0.096890+0.000850
# [14]	train-rmse:0.096423+0.000440	test-rmse:0.096826+0.000834
# [15]	train-rmse:0.096372+0.000428	test-rmse:0.096783+0.000856
# [16]	train-rmse:0.096293+0.000419	test-rmse:0.096719+0.000879
# [17]	train-rmse:0.096234+0.000415	test-rmse:0.096658+0.000889
# [18]	train-rmse:0.096170+0.000421	test-rmse:0.096598+0.000886
# [19]	train-rmse:0.096096+0.000432	test-rmse:0.096530+0.000871
# [20]	train-rmse:0.096057+0.000445	test-rmse:0.096514+0.000870
# [21]	train-rmse:0.095988+0.000479	test-rmse:0.096461+0.000842
# [22]	train-rmse:0.095955+0.000474	test-rmse:0.096453+0.000854
# [23]	train-rmse:0.095905+0.000475	test-rmse:0.096418+0.000872
# [24]	train-rmse:0.095866+0.000469	test-rmse:0.096392+0.000889
# [85]	train-rmse:0.167455+0.000618	test-rmse:0.168164+0.001192
# [86]	train-rmse:0.167430+0.000612	test-rmse:0.168150+0.001187
# [87]	train-rmse:0.167411+0.000615	test-rmse:0.168138+0.001189
# [88]	train-rmse:0.167398+0.000617	test-rmse:0.168130+0.001188
# [89]	train-rmse:0.167385+0.000619	test-rmse:0.168120+0.001182
# [90]	train-rmse:0.167367+0.000621	test-rmse:0.168103+0.001182
# [91]	train-rmse:0.167351+0.000621	test-rmse:0.168091+0.001177
# [92]	train-rmse:0.167338+0.000623	test-rmse:0.168091+0.001180
# [93]	train-rmse:0.167326+0.000621	test-rmse:0.168083+0.001179
# [94]	train-rmse:0.167317+0.000621	test-rmse:0.168081+0.001182
# [95]	train-rmse:0.167309+0.000621	test-rmse:0.168080+0.001181
# [96]	train-rmse:0.167295+0.000631	test-rmse:0.168073+0.001170
# [97]	train-rmse:0.167284+0.000630	test-rmse:0.168072+0.001173
# [98]	train-rmse:0.167270+0.000626	test-rmse:0.168069+0.001164
# [99]	train-rmse:0.167259+0.000627	test-rmse:0.168060+0.001164
# [100]	train-rmse:0.167247+0.000629	test-rmse:0.168053+0.001160
# [1] "stalter_p1sdp_m10"
# [1]	train-rmse:0.251262+0.000044	test-rmse:0.251261+0.000089
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.127499+0.000087	test-rmse:0.127500+0.000178
# [3]	train-rmse:0.067353+0.000165	test-rmse:0.067353+0.000333
# [4]	train-rmse:0.040072+0.000275	test-rmse:0.040073+0.000554
# [5]	train-rmse:0.029541+0.000374	test-rmse:0.029538+0.000754
# [6]	train-rmse:0.026253+0.000419	test-rmse:0.026248+0.000856
# [7]	train-rmse:0.025360+0.000432	test-rmse:0.025355+0.000887
# [8]	train-rmse:0.025125+0.000438	test-rmse:0.025123+0.000894
# [9]	train-rmse:0.025056+0.000441	test-rmse:0.025057+0.000895
# [10]	train-rmse:0.025039+0.000442	test-rmse:0.025041+0.000895
# [11]	train-rmse:0.025026+0.000448	test-rmse:0.025030+0.000890
# [12]	train-rmse:0.025020+0.000449	test-rmse:0.025027+0.000892
# [13]	train-rmse:0.025018+0.000449	test-rmse:0.025024+0.000891
# [14]	train-rmse:0.025005+0.000456	test-rmse:0.025014+0.000885
# [15]	train-rmse:0.024999+0.000457	test-rmse:0.025008+0.000881
# [16]	train-rmse:0.024996+0.000457	test-rmse:0.025007+0.000881
# [17]	train-rmse:0.024993+0.000459	test-rmse:0.025006+0.000881
# [18]	train-rmse:0.024990+0.000457	test-rmse:0.025006+0.000880
# [19]	train-rmse:0.024988+0.000458	test-rmse:0.025005+0.000879
# [20]	train-rmse:0.024985+0.000455	test-rmse:0.025004+0.000880
# [21]	train-rmse:0.024981+0.000457	test-rmse:0.025001+0.000878
# [22]	train-rmse:0.024979+0.000456	test-rmse:0.025000+0.000879
# [23]	train-rmse:0.024967+0.000446	test-rmse:0.024986+0.000891
# [24]	train-rmse:0.024961+0.000440	test-rmse:0.024984+0.000895
# [25]	train-rmse:0.024958+0.000440	test-rmse:0.024983+0.000894
# [26]	train-rmse:0.024957+0.000440	test-rmse:0.024982+0.000894
# [95]	train-rmse:0.042420+0.000533	test-rmse:0.042711+0.001083
# [96]	train-rmse:0.042416+0.000533	test-rmse:0.042708+0.001083
# [97]	train-rmse:0.042400+0.000529	test-rmse:0.042697+0.001087
# [98]	train-rmse:0.042396+0.000532	test-rmse:0.042697+0.001087
# [99]	train-rmse:0.042393+0.000535	test-rmse:0.042696+0.001087
# [100]	train-rmse:0.042390+0.000536	test-rmse:0.042698+0.001088

# %%
df %>%
    select(key, date, n, cluster, fold) %>%
    bind_cols(xg.residuals) -> df.r

# %%
write_rds(df.r, str_c(fp, 'PROCESSED_DATA/panel_xgr_v2.RDS'))

# %% [raw]
# XGresidualizer <- function(Y, colname) {
#     print(colname)
#     if(str_detect(colname, 'l[1-7]')) {
#         residualizer_df %>%
#             mutate(Y = Y) %>%
#             group_by(key) %>%
#             arrange(key, date) %>%
#             filter(row_number() > as.numeric(str_sub(colname, -1, -1))) %>%
#             arrange(date, key) %>%
#             ungroup() -> temp_df
#
#         temp_df %>%
#             ungroup() %>%
#             arrange(date, key) %>%
#             mutate(Y.r = felm(Y ~ 0 | key + date, ., weights = temp_df$n)$resid) %>%
#             arrange(date, key) -> temp_df
#
#     } else {
#         residualizer_df %>%
#             ungroup() %>%
#             mutate(Y = Y,
#                    Y.r = felm(Y ~ 0 | key + date, ., weights = residualizer_df$n)$resid) -> temp_df
#     }
#
#     folds <- list(which(temp_df$fold %in% 1),
#                   which(temp_df$fold %in% 2),
#                   which(temp_df$fold %in% 3))
#
#     dm    <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe, temp_df), label = temp_df$Y.r)
#     param <- list(max_depth=2, eta=.5, silent=1, objective='reg:linear')
#     fit   <- xgb.cv(params = param,
#                     data = dm,
#                     folds = folds,
#                     nrounds = 100,
#                     early_stopping_rounds = 3,
#                     weight = temp_df$n)
#     best_n <- fit$best_iteration
#     for (i in 1:3) {
#         tr  <- temp_df %>% filter(fold != i)
#         trm <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe, tr), label = tr$Y.r)
#         fit <- xgb.train(params = param,
#                          data = trm,
#                          nrounds = best_n,
#                          weight = tr$n)
#         te  <- temp_df %>% filter(fold == i)
#         tem <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe, te), label = te$Y.r)
#         te %>%
#             select(date, key) %>%
#             mutate(pred = predict(fit, newdata = tem)) -> pred_df
#         assign(str_c('temp',i), pred_df) %>%
#         select(-pred, -date, -key)
#     }
#     if(str_detect(colname, 'l[1-7]')) {
#         out <- residualizer_df %>%
#             select(date, key) %>%
#             left_join(bind_rows(temp1, temp2, temp3) %>%
#                       mutate(tempname = temp_df$Y.r - pred)) %>%
#             arrange(date, key) %>%
#             select(-pred, -date, -key)
#     } else {
#         out <- bind_rows(temp1, temp2, temp3) %>%
#             arrange(date, key) %>%
#             mutate(tempname = temp_df$Y.r - pred) %>%
#             select(-pred, -date, -key)
#     }
#     colnames(out) <- str_c(colname, '.r')
#     return(out)
# }
