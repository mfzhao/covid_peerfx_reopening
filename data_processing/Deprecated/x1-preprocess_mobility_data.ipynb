# %%
library(dplyr)
library(tidyr)
library(readr)
library(doMC)
library(stringr)
registerDoMC(cores = 28)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: foreach
#
# Loading required package: iterators
#
# Loading required package: parallel

# %%
flist <- Sys.glob('/pool001/mfzhao/mobility/*/*')
eu_mobility <- foreach(f = flist[!str_detect(flist, 'united_states')], .combine = 'rbind') %dopar% read_csv(f)
us_mobility <- foreach(f = flist[str_detect(flist, 'united_states')], .combine = 'rbind') %dopar% read_csv(f)

# %%
us_mobility %>%
    arrange(ds, polygon_id) %>%
    filter(ds == as.Date('2020-03-01'))
# Out:
#      ds         crisis_name polygon_id polygon_name  age_bracket gender
# 1    2020-03-01 US_county   1001       Autauga       Overall     Overall
# 2    2020-03-01 US_county   1003       Baldwin       Overall     Overall
# 3    2020-03-01 US_county   1005       Barbour       Overall     Overall
# 4    2020-03-01 US_county   1007       Bibb          Overall     Overall
# 5    2020-03-01 US_county   1009       Blount        Overall     Overall
# 6    2020-03-01 US_county   1011       Bullock       Overall     Overall
# 7    2020-03-01 US_county   1013       Butler        Overall     Overall
# 8    2020-03-01 US_county   1015       Calhoun       Overall     Overall
# 9    2020-03-01 US_county   1017       Chambers      Overall     Overall
# 10   2020-03-01 US_county   1019       Cherokee      Overall     Overall
# 11   2020-03-01 US_county   1021       Chilton       Overall     Overall
# 12   2020-03-01 US_county   1023       Choctaw       Overall     Overall
# 13   2020-03-01 US_county   1025       Clarke        Overall     Overall
# 14   2020-03-01 US_county   1027       Clay          Overall     Overall
# 15   2020-03-01 US_county   1029       Cleburne      Overall     Overall
# 16   2020-03-01 US_county   1031       Coffee        Overall     Overall
# 17   2020-03-01 US_county   1033       Colbert       Overall     Overall
# 18   2020-03-01 US_county   1035       Conecuh       Overall     Overall
# 19   2020-03-01 US_county   1037       Coosa         Overall     Overall
# 20   2020-03-01 US_county   1039       Covington     Overall     Overall
# 21   2020-03-01 US_county   1041       Crenshaw      Overall     Overall
# 22   2020-03-01 US_county   1043       Cullman       Overall     Overall
# 23   2020-03-01 US_county   1045       Dale          Overall     Overall
# 24   2020-03-01 US_county   1047       Dallas        Overall     Overall
# 25   2020-03-01 US_county   1049       DeKalb        Overall     Overall
# 26   2020-03-01 US_county   1051       Elmore        Overall     Overall
# 27   2020-03-01 US_county   1053       Escambia      Overall     Overall
# 28   2020-03-01 US_county   1055       Etowah        Overall     Overall
# 29   2020-03-01 US_county   1057       Fayette       Overall     Overall
# 30   2020-03-01 US_county   1059       Franklin      Overall     Overall
# ⋮    ⋮          ⋮           ⋮          ⋮             ⋮           ⋮
# 2609 2020-03-01 US_county   72099      Moca          Overall     Overall
# 2610 2020-03-01 US_county   72101      Morovis       Overall     Overall
# 2611 2020-03-01 US_county   72103      Naguabo       Overall     Overall
# 2612 2020-03-01 US_county   72105      Naranjito     Overall     Overall
# 2613 2020-03-01 US_county   72107      Orocovis      Overall     Overall
# 23   full_february_except_presidents_day DAY_OF_WEEK
# 24   full_february_except_presidents_day DAY_OF_WEEK
# 25   full_february_except_presidents_day DAY_OF_WEEK
# 26   full_february_except_presidents_day DAY_OF_WEEK
# 27   full_february_except_presidents_day DAY_OF_WEEK
# 28   full_february_except_presidents_day DAY_OF_WEEK
# 29   full_february_except_presidents_day DAY_OF_WEEK
# 30   full_february_except_presidents_day DAY_OF_WEEK
# ⋮    ⋮                                   ⋮
# 2609 full_february_except_presidents_day DAY_OF_WEEK
# 2610 full_february_except_presidents_day DAY_OF_WEEK
# 2611 full_february_except_presidents_day DAY_OF_WEEK
# 2612 full_february_except_presidents_day DAY_OF_WEEK
# 2613 full_february_except_presidents_day DAY_OF_WEEK
# 2614 full_february_except_presidents_day DAY_OF_WEEK
# 2615 full_february_except_presidents_day DAY_OF_WEEK
# 2616 full_february_except_presidents_day DAY_OF_WEEK
# 2617 full_february_except_presidents_day DAY_OF_WEEK
# 2618 full_february_except_presidents_day DAY_OF_WEEK
# 2619 full_february_except_presidents_day DAY_OF_WEEK
# 2620 full_february_except_presidents_day DAY_OF_WEEK
# 2621 full_february_except_presidents_day DAY_OF_WEEK
# 2622 full_february_except_presidents_day DAY_OF_WEEK
# 2623 full_february_except_presidents_day DAY_OF_WEEK
# 2624 full_february_except_presidents_day DAY_OF_WEEK
# 2625 full_february_except_presidents_day DAY_OF_WEEK
# 2626 full_february_except_presidents_day DAY_OF_WEEK
# 2627 full_february_except_presidents_day DAY_OF_WEEK
# 2628 full_february_except_presidents_day DAY_OF_WEEK
# 2629 full_february_except_presidents_day DAY_OF_WEEK
# 2630 full_february_except_presidents_day DAY_OF_WEEK
# 2631 full_february_except_presidents_day DAY_OF_WEEK
# 2632 full_february_except_presidents_day DAY_OF_WEEK
# 2633 full_february_except_presidents_day DAY_OF_WEEK
# 2634 full_february_except_presidents_day DAY_OF_WEEK
# 2635 full_february_except_presidents_day DAY_OF_WEEK
# 2636 full_february_except_presidents_day DAY_OF_WEEK
# 2637 full_february_except_presidents_day DAY_OF_WEEK
# 2638 full_february_except_presidents_day DAY_OF_WEEK
#      all_day_bing_tiles_visited_relative_change all_day_ratio_single_tile_users
# 1     0.0484494125                              0.1891036
# 2     0.1429764399                              0.1720912
# 3     0.1948150081                              0.1477137
# 4     0.0784205232                              0.1651653
# 5     0.0364588878                              0.1999208
# 6     0.1600880985                              0.1542295
# 7     0.1525933141                              0.1759363
# 8     0.0431625529                              0.1777367
# 9     0.0683377245                              0.1773198
# 10    0.0772998711                              0.2047176
# 11    0.0643297319                              0.1571401
# 12    0.0413989236                              0.1711380
# 13    0.0181114061                              0.1764428
# 14    0.0297254088                              0.2062028
# 15    0.0915994092                              0.2006192
# 16    0.0406156155                              0.1901588
# 17    0.0110462381                              0.1818047
# 18    0.1150026730                              0.1709460
# 19    0.0377898134                              0.1950808
# 20   -0.0005178506                              0.1854893
# 2625 FIPS                     72131
# 2626 FIPS                     72133
# 2627 FIPS                     72135
# 2628 FIPS                     72137
# 2629 FIPS                     72139
# 2630 FIPS                     72141
# 2631 FIPS                     72143
# 2632 FIPS                     72145
# 2633 FIPS                     72147
# 2634 FIPS                     72149
# 2635 FIPS                     72151
# 2636 FIPS                     72153
# 2637 FIPS                     78010
# 2638 FIPS                     78030

# %%
eu_mobility %>% 
    filter(baseline_name != 'limited_february') %>%
    select(key = external_polygon_id,
           ds, 
           btvrc = all_day_bing_tiles_visited_relative_change, 
           rstu = all_day_ratio_single_tile_users) %>%
    arrange(key, ds) %>%
    mutate(key = ifelse(key == 'UKN0A', 'UKN10', key),
           key = ifelse(key == 'UKN0B', 'UKN11', key),
           key = ifelse(key == 'UKN0C', 'UKN12', key),
           key = ifelse(key == 'UKN0D', 'UKN13', key),
           key = ifelse(key == 'UKN0E', 'UKN14', key),
           key = ifelse(key == 'UKN0F', 'UKN15', key),
           key = ifelse(key == 'UKN0G', 'UKN16', key)) -> eu_mobility

us_mobility %>% 
    filter(baseline_name != 'limited_february') %>%
    select(key = external_polygon_id,
           ds, 
           btvrc = all_day_bing_tiles_visited_relative_change, 
           rstu = all_day_ratio_single_tile_users) %>%
    mutate(key = str_pad(key, 5, pad = '0')) %>%
    arrange(key, ds) -> us_mobility

# %%
eu_pop <- read_delim('/pool001/mfzhao/geo_data/europe_population.tsv', '\t', escape_double = FALSE, trim_ws = TRUE)

eu_pop %>%
    separate('sex,unit,age,geo\\time', into = c('sex', 'unit', 'age', 'key'), sep = ',') %>%
    filter(sex == 'T', age == 'TOTAL') %>%
    select(key, n = `2018`) %>%
    mutate(n = str_replace(n, ' p', ''),
           n = as.numeric(n)) -> eu_pop
# Out:
# Parsed with column specification:
# cols(
#   `sex,unit,age,geo\time` = col_character(),
#   `2019` = col_character(),
#   `2018` = col_character(),
#   `2017` = col_character(),
#   `2016` = col_character(),
#   `2015` = col_character(),
#   `2014` = col_character()
# )
#
# Warning message:
# “NAs introduced by coercion”

# %%
us_pop <- read_csv('/pool001/mfzhao/geo_data/cc-est2018-alldata.csv')

us_pop %>%
    unite('key', STATE, COUNTY, sep = '') %>%
    filter(YEAR == 11, 
           AGEGRP==0) %>% 
    group_by(key) %>%
    summarize(n = sum(TOT_POP)) -> us_pop
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   SUMLEV = col_character(),
#   STATE = col_character(),
#   COUNTY = col_character(),
#   STNAME = col_character(),
#   CTYNAME = col_character()
# )
#
# See spec(...) for full column specifications.

# %%
eu_mobility %>% 
    inner_join(eu_pop) -> eu_mobility

us_mobility %>% 
    inner_join(us_pop) -> us_mobility
# Out:
# Joining, by = "key"
#
# Joining, by = "key"

# %%
write_csv(eu_mobility, '/pool001/mfzhao/PROCESSED_DATA/eu_mobility.csv')
write_csv(us_mobility, '/pool001/mfzhao/PROCESSED_DATA/us_mobility.csv')
