# %%
library(readr)
library(dplyr)
library(tidyr)
library(stringr)
library(doMC)
library(lfe)
library(xgboost)
registerDoMC(20)

# %%
fp <- '/pool001/mfzhao/'
df <- read_rds(str_c(fp, 'PROCESSED_DATA/panel_pre_xgr.RDS'))

# %%
df %>%
    arrange(key, date) %>%
    group_by(key) %>%
    mutate_at(vars(p1sdp, p2shp, p3rop, stalter_p1sdp, stalter_p2shp, stalter_p3rop),
              .funs = list(l01 = function(x) lag(x),
                           l02 = function(x) lag(x, 2),
                           l03 = function(x) lag(x, 3),
                           l04 = function(x) lag(x, 4),
                           l05 = function(x) lag(x, 5),
                           l06 = function(x) lag(x, 6),
                           l07 = function(x) lag(x, 7),
                           l08 = function(x) lag(x, 8),
                           l09 = function(x) lag(x, 9),
                           l10 = function(x) lag(x, 10),
                           m01 = function(x) lead(x),
                           m02 = function(x) lead(x, 2),
                           m03 = function(x) lead(x, 3),
                           m04 = function(x) lead(x, 4),
                           m05 = function(x) lead(x, 5),
                           m06 = function(x) lead(x, 6),
                           m07 = function(x) lead(x, 7),
                           m08 = function(x) lead(x, 8),
                           m09 = function(x) lead(x, 9),
                           m10 = function(x) lead(x, 10))) -> df

df %>%
    fill(matches("m[01][0-9]"), .direction = 'down') %>%
    fill(matches("l[01][0-9]"), .direction = 'up') -> df

# %%
set.seed(2345)
df %>%
    ungroup() %>%
    select(key) %>%
    distinct() %>% 
    mutate(i = sample(1:n(), n(), replace = F),
           fold = i %% 3 + 1) %>%
    select(-i) -> folds

df %>%
    inner_join(folds) %>%
    arrange(date, key) %>%
    ungroup() -> df

df %>%
    ungroup() %>%
    mutate(PRCP.r_fe      = felm(PRCP ~ 0 | key + date, ., weights = df$n)$resid,
           TMAX.r_fe      = felm(TMAX ~ 0 | key + date, ., weights = df$n)$resid,
           newcases.r_fe  = felm(newcases ~ 0 | key + date, ., weights = df$n)$resid,
           newdeaths.r_fe = felm(newdeaths ~ 0 | key + date, ., weights = df$n)$resid,
           newcases_state.r_fe  = felm(newcases ~ 0 | key + date, ., weights = df$n)$resid,
           newdeaths_state.r_fe = felm(newdeaths ~ 0 | key + date, ., weights = df$n)$resid) %>%
    select(date, 
           key, 
           PRCP.r_fe, 
           TMAX.r_fe, 
           newcases.r_fe, 
           newdeaths.r_fe, 
           newcases_state.r_fe, 
           newdeaths_state.r_fe, 
           fold, 
           n) -> residualizer_df

folds <- list(which(folds$fold %in% 1), 
              which(folds$fold %in% 2), 
              which(folds$fold %in% 3))

write_rds(folds, str_c(fp, 'PROCESSED_DATA/folds.RDS'))
write_rds(residualizer_df, str_c(fp, 'PROCESSED_DATA/residualizer_data.RDS'))
# Out:
# Joining, by = "key"

# %%
XGresidualizer <- function(Y, colname) {
    print(colname)
    residualizer_df %>%
        ungroup() %>% 
        mutate(Y = Y,
               Y.r = felm(Y ~ 0 | key + date, ., weights = residualizer_df$n)$resid) -> temp_df
  
    folds <- list(which(temp_df$fold %in% 1), 
                  which(temp_df$fold %in% 2), 
                  which(temp_df$fold %in% 3))
    
    X     <- model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe + newcases.r_fe + newdeaths.r_fe + 
                            newcases_state.r_fe + newdeaths_state.r_fe, temp_df)
    dm    <- xgb.DMatrix(data = X, label = temp_df$Y.r)
    param <- list(max_depth=2, eta=.5, silent=1, objective='reg:linear')
    fit   <- xgb.cv(params = param, 
                    data = dm, 
                    folds = folds,
                    nrounds = 100, 
                    early_stopping_rounds = 3, 
                    weight = temp_df$n,
                    nthread = 20)
    best_n <- fit$best_iteration
    for (i in 1:3) {
        tr  <- temp_df %>% filter(fold != i)
        trm <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe + newcases.r_fe + newdeaths.r_fe + 
                                                 newcases_state.r_fe + newdeaths_state.r_fe, tr), label = tr$Y.r)
        fit <- xgb.train(params = param, 
                         data = trm, 
                         nrounds = best_n, 
                         weight = tr$n,
                         nthread = 20)
        te  <- temp_df %>% filter(fold == i)
        tem <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe + newcases.r_fe + newdeaths.r_fe + 
                                                 newcases_state.r_fe + newdeaths_state.r_fe, te), label = te$Y.r)
        te %>%
            select(date, key) %>%
            mutate(pred = predict(fit, newdata = tem)) -> pred_df
        assign(str_c('temp',i), pred_df) %>%
        select(-pred, -date, -key)
    }
    out <- bind_rows(temp1, temp2, temp3) %>%
        arrange(date, key) %>%
        mutate(tempname = temp_df$Y.r - pred) %>%
        select(-pred, -date, -key)
    
    colnames(out) <- str_c(colname, '.r')
    return(out)
}

# %%
cols_to_xgr <- colnames(
    df %>%
        select(
            -cases,
            -newcases,
            -deaths,
            -newdeaths,
            -matches('^d'),
            -matches('^pc'),
            -matches('alter_d'),
            -matches('alter_pc'),
            -matches('log_d'),
            -matches('log_pc'),
            -date,
            -key,
            -cluster,
            -n,
            -fold,
            -matches('PRCP', ignore.case = F),
            -matches('TMAX', ignore.case = F),
            -matches('^prcp..'),
            -matches('^tmax..'),
            -matches('alter_.*_p[123]...$')
         )
)
cols_to_xgr
# Out:
#   [1] "mcbgv"                "pnchd"                "pgt1hafh"
#   [4] "ppthlt75"             "pgt2kmt"              "p1sdp"
#   [7] "p2shp"                "p3rop"                "p1sdpDSS"
#  [10] "p2shpDSS"             "p3ropDSS"             "mcbgv_p1sdp"
#  [13] "pnchd_p1sdp"          "pgt1hafh_p1sdp"       "ppthlt75_p1sdp"
#  [16] "pgt2kmt_p1sdp"        "mcbgv_p2shp"          "pnchd_p2shp"
#  [19] "pgt1hafh_p2shp"       "ppthlt75_p2shp"       "pgt2kmt_p2shp"
#  [22] "mcbgv_p3rop"          "pnchd_p3rop"          "pgt1hafh_p3rop"
#  [25] "ppthlt75_p3rop"       "pgt2kmt_p3rop"        "stalter_mcbgv"
#  [28] "stalter_pnchd"        "stalter_pgt1hafh"     "stalter_ppthlt75"
#  [31] "stalter_pgt2kmt"      "stalter_p1sdp"        "stalter_p2shp"
#  [34] "stalter_p3rop"        "stalter_p1sdpDSS"     "stalter_p2shpDSS"
#  [37] "stalter_p3ropDSS"     "stalter_prcp01"       "stalter_prcp02"
#  [40] "stalter_prcp03"       "stalter_prcp04"       "stalter_prcp05"
#  [43] "stalter_prcp06"       "stalter_prcp07"       "stalter_prcp08"
#  [46] "stalter_prcp09"       "stalter_prcp10"       "stalter_tmax02"
#  [49] "stalter_tmax03"       "stalter_tmax04"       "stalter_tmax05"
#  [52] "stalter_tmax06"       "stalter_tmax07"       "stalter_tmax08"
#  [55] "stalter_tmax09"       "stalter_tmax10"       "alter_mcbgv"
#  [58] "alter_pnchd"          "alter_pgt1hafh"       "alter_ppthlt75"
#  [61] "alter_pgt2kmt"        "alter_p1sdp"          "alter_p2shp"
#  [64] "alter_p3rop"          "alter_p1sdpDSS"       "alter_p2shpDSS"
#  [67] "alter_p3ropDSS"       "alter_prcp01"         "alter_prcp02"
#  [70] "alter_prcp03"         "alter_prcp04"         "alter_prcp05"
#  [73] "alter_prcp06"         "alter_prcp07"         "alter_prcp08"
#  [76] "alter_prcp09"         "alter_prcp10"         "alter_tmax02"
#  [79] "alter_tmax03"         "alter_tmax04"         "alter_tmax05"
#  [82] "alter_tmax06"         "alter_tmax07"         "alter_tmax08"
#  [85] "alter_tmax09"         "alter_tmax10"         "stalterNear_p1sdp"
#  [88] "stalterNear_p2shp"    "stalterNear_p3rop"    "stalterFar_p1sdp"
#  [91] "stalterFar_p2shp"     "stalterFar_p3rop"     "log_mcbgv"
#  [94] "log_pnchd"            "log_pgt1hafh"         "log_ppthlt75"
#  [97] "log_pgt2kmt"          "log_stalter_mcbgv"    "log_stalter_pnchd"
# [100] "log_stalter_pgt1hafh" "log_stalter_ppthlt75" "log_stalter_pgt2kmt"
# [103] "log_alter_mcbgv"      "log_alter_pnchd"      "log_alter_pgt1hafh"
# [106] "log_alter_ppthlt75"   "log_alter_pgt2kmt"    "stnewcases"
# [109] "stnewdeaths"          "p1sdp_l01"            "p2shp_l01"
# [112] "p3rop_l01"            "stalter_p1sdp_l01"    "stalter_p2shp_l01"
# [115] "stalter_p3rop_l01"    "p1sdp_l02"            "p2shp_l02"
# [118] "p3rop_l02"            "stalter_p1sdp_l02"    "stalter_p2shp_l02"
# [121] "stalter_p3rop_l02"    "p1sdp_l03"            "p2shp_l03"
# [124] "p3rop_l03"            "stalter_p1sdp_l03"    "stalter_p2shp_l03"
# [127] "stalter_p3rop_l03"    "p1sdp_l04"            "p2shp_l04"
# [130] "p3rop_l04"            "stalter_p1sdp_l04"    "stalter_p2shp_l04"
# [133] "stalter_p3rop_l04"    "p1sdp_l05"            "p2shp_l05"
# [136] "p3rop_l05"            "stalter_p1sdp_l05"    "stalter_p2shp_l05"
# [139] "stalter_p3rop_l05"    "p1sdp_l06"            "p2shp_l06"
# [142] "p3rop_l06"            "stalter_p1sdp_l06"    "stalter_p2shp_l06"
# [145] "stalter_p3rop_l06"    "p1sdp_l07"            "p2shp_l07"
# [148] "p3rop_l07"            "stalter_p1sdp_l07"    "stalter_p2shp_l07"
# [151] "stalter_p3rop_l07"    "p1sdp_l08"            "p2shp_l08"
# [154] "p3rop_l08"            "stalter_p1sdp_l08"    "stalter_p2shp_l08"
# [157] "stalter_p3rop_l08"    "p1sdp_l09"            "p2shp_l09"
# [160] "p3rop_l09"            "stalter_p1sdp_l09"    "stalter_p2shp_l09"
# [163] "stalter_p3rop_l09"    "p1sdp_l10"            "p2shp_l10"
# [166] "p3rop_l10"            "stalter_p1sdp_l10"    "stalter_p2shp_l10"
# [169] "stalter_p3rop_l10"    "p1sdp_m01"            "p2shp_m01"
# [172] "p3rop_m01"            "stalter_p1sdp_m01"    "stalter_p2shp_m01"
# [175] "stalter_p3rop_m01"    "p1sdp_m02"            "p2shp_m02"
# [178] "p3rop_m02"            "stalter_p1sdp_m02"    "stalter_p2shp_m02"
# [181] "stalter_p3rop_m02"    "p1sdp_m03"            "p2shp_m03"
# [184] "p3rop_m03"            "stalter_p1sdp_m03"    "stalter_p2shp_m03"
# [187] "stalter_p3rop_m03"    "p1sdp_m04"            "p2shp_m04"
# [190] "p3rop_m04"            "stalter_p1sdp_m04"    "stalter_p2shp_m04"
# [193] "stalter_p3rop_m04"    "p1sdp_m05"            "p2shp_m05"
# [196] "p3rop_m05"            "stalter_p1sdp_m05"    "stalter_p2shp_m05"
# [199] "stalter_p3rop_m05"    "p1sdp_m06"            "p2shp_m06"
# [202] "p3rop_m06"            "stalter_p1sdp_m06"    "stalter_p2shp_m06"
# [205] "stalter_p3rop_m06"    "p1sdp_m07"            "p2shp_m07"
# [208] "p3rop_m07"            "stalter_p1sdp_m07"    "stalter_p2shp_m07"
# [211] "stalter_p3rop_m07"    "p1sdp_m08"            "p2shp_m08"
# [214] "p3rop_m08"            "stalter_p1sdp_m08"    "stalter_p2shp_m08"
# [217] "stalter_p3rop_m08"    "p1sdp_m09"            "p2shp_m09"
# [220] "p3rop_m09"            "stalter_p1sdp_m09"    "stalter_p2shp_m09"
# [223] "stalter_p3rop_m09"    "p1sdp_m10"            "p2shp_m10"
# [226] "p3rop_m10"            "stalter_p1sdp_m10"    "stalter_p2shp_m10"
# [229] "stalter_p3rop_m10"

# %%
xg.residuals <- foreach(i = 1:length(cols_to_xgr), .combine = cbind) %do% XGresidualizer(df[[cols_to_xgr[i]]], cols_to_xgr[i])

# %%
df %>%
    select(key, date, n, cluster, fold) %>%
    bind_cols(xg.residuals) -> df.r

# %%
write_rds(df.r, str_c(fp, 'PROCESSED_DATA/panel_xgr_v2.RDS'))

# %% [raw]
# XGresidualizer <- function(Y, colname) {
#     print(colname)
#     if(str_detect(colname, 'l[1-7]')) {
#         residualizer_df %>%
#             mutate(Y = Y) %>%
#             group_by(key) %>%
#             arrange(key, date) %>%
#             filter(row_number() > as.numeric(str_sub(colname, -1, -1))) %>%
#             arrange(date, key) %>%
#             ungroup() -> temp_df
#
#         temp_df %>%
#             ungroup() %>%
#             arrange(date, key) %>%
#             mutate(Y.r = felm(Y ~ 0 | key + date, ., weights = temp_df$n)$resid) %>%
#             arrange(date, key) -> temp_df
#
#     } else {
#         residualizer_df %>%
#             ungroup() %>%
#             mutate(Y = Y,
#                    Y.r = felm(Y ~ 0 | key + date, ., weights = residualizer_df$n)$resid) -> temp_df
#     }
#
#     folds <- list(which(temp_df$fold %in% 1),
#                   which(temp_df$fold %in% 2),
#                   which(temp_df$fold %in% 3))
#
#     dm    <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe, temp_df), label = temp_df$Y.r)
#     param <- list(max_depth=2, eta=.5, silent=1, objective='reg:linear')
#     fit   <- xgb.cv(params = param,
#                     data = dm,
#                     folds = folds,
#                     nrounds = 100,
#                     early_stopping_rounds = 3,
#                     weight = temp_df$n)
#     best_n <- fit$best_iteration
#     for (i in 1:3) {
#         tr  <- temp_df %>% filter(fold != i)
#         trm <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe, tr), label = tr$Y.r)
#         fit <- xgb.train(params = param,
#                          data = trm,
#                          nrounds = best_n,
#                          weight = tr$n)
#         te  <- temp_df %>% filter(fold == i)
#         tem <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.r_fe + TMAX.r_fe, te), label = te$Y.r)
#         te %>%
#             select(date, key) %>%
#             mutate(pred = predict(fit, newdata = tem)) -> pred_df
#         assign(str_c('temp',i), pred_df) %>%
#         select(-pred, -date, -key)
#     }
#     if(str_detect(colname, 'l[1-7]')) {
#         out <- residualizer_df %>%
#             select(date, key) %>%
#             left_join(bind_rows(temp1, temp2, temp3) %>%
#                       mutate(tempname = temp_df$Y.r - pred)) %>%
#             arrange(date, key) %>%
#             select(-pred, -date, -key)
#     } else {
#         out <- bind_rows(temp1, temp2, temp3) %>%
#             arrange(date, key) %>%
#             mutate(tempname = temp_df$Y.r - pred) %>%
#             select(-pred, -date, -key)
#     }
#     colnames(out) <- str_c(colname, '.r')
#     return(out)
# }
