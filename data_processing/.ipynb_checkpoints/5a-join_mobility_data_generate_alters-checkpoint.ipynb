# %%
library(readr)
library(dplyr)
library(tidyr)
library(stringr)
library(doMC)
library(lubridate)
registerDoMC(20)
# Out:
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     intersect, setdiff, union
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
fp <- '/pool001/mfzhao/'
weather     <- read_csv(str_c(fp, 'PROCESSED_DATA/region_weather_2020.csv'))
policy      <- read_csv(str_c(fp, 'PROCESSED_DATA/policy.csv'))
sci         <- read_delim(str_c(fp, 'sci/SCI_county.tsv'),  "\t", escape_double = FALSE, trim_ws = TRUE)
us_pop      <- read_csv('/pool001/mfzhao/geo_data/cc-est2018-alldata.csv')
us_mobility <- read_csv(str_c(fp, 'safegraph/us_mobility.csv'), 
                        col_types = cols(
                            mhdt = col_double(),
                            mnhdt = col_double(),
                            mdtfh = col_double()))
# Out:
# Parsed with column specification:
# cols(
#   key = col_character(),
#   DATE = col_date(format = ""),
#   PRCP = col_double(),
#   TMAX = col_double()
# )
#
# Parsed with column specification:
# cols(
#   key = col_character(),
#   date = col_date(format = ""),
#   cluster = col_character(),
#   reopening = col_double(),
#   sdPolicy = col_double(),
#   stayHome = col_double()
# )
#
# Parsed with column specification:
# cols(
#   user_county = col_character(),
#   fr_county = col_character(),
#   scaled_sci = col_double()
# )
#
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   SUMLEV = col_character(),
#   STATE = col_character(),
#   COUNTY = col_character(),
#   STNAME = col_character(),
#   CTYNAME = col_character()
# )
#
# See spec(...) for full column specifications.

# %%
us_pop %>%
    unite('key', STATE, COUNTY, sep = '') %>%
    filter(YEAR == 11, 
           AGEGRP==0) %>% 
    group_by(key) %>%
    summarize(n = sum(TOT_POP)) -> us_pop

us_mobility %>%
    rename(key = origin_county) %>%
    filter(date >= as.Date('2020-03-01'), date < as.Date('2020-07-01')) %>%
    left_join(us_pop) -> us_mobility

us_mobility %>%
    group_by(key) %>%
    filter(key < '57000') %>%
    tally() %>%
    filter(n == max(n))%>%
    select(key) %>%
    left_join(us_mobility) -> us_mobility
# Out:
# Joining, by = "key"
#
# Joining, by = "key"

# %%
us_mobility %>%
    group_by(key) %>%
    tally() %>%
    filter(n == max(n)) %>%
    select(key) -> keys_mobility

policy %>%
    select(key) %>%
    distinct() -> keys_policy

weather %>%
    select(key) %>%
    distinct() %>%
    anti_join(weather %>% 
              filter(is.na(PRCP) | is.na(TMAX)) %>%
              select(key) %>%
              distinct()) -> keys_weather

sci %>%
    select(key = user_county) %>%
    distinct() -> keys_sci

keys_mobility %>%
    inner_join(keys_policy) %>%
    inner_join(keys_weather) %>%
    inner_join(keys_sci) -> keys

write_csv(keys, str_c(fp, 'PROCESSED_DATA/keys.csv'))
# Out:
# Joining, by = "key"
#
# Joining, by = "key"
#
# Joining, by = "key"
#
# Joining, by = "key"

# %%
us_mobility %>%
    select(key, n) %>%
    distinct() %>%
    inner_join(keys) %>%
    mutate(nquant = ntile(n, 2)) -> population
# Out:
# Joining, by = "key"

# %%
sci %>%
    inner_join(keys, by = c('user_county' = 'key')) %>%
    inner_join(keys, by = c('fr_county' = 'key'))  %>%
    inner_join(population, by = c('fr_county' = 'key')) %>% 
    arrange(user_county, fr_county) -> sci

write_csv(sci, str_c(fp, 'PROCESSED_DATA/processed_sci.csv'))

# %%
sci %>%
    group_by(user_county) %>%
    mutate(w = ifelse(user_county == fr_county, 0, scaled_sci * n),
           w = w/sum(w)) %>%
    select(key = user_county, fr_county, w) %>%
    spread(key = fr_county, value = w) %>%
    ungroup(key) %>%
    arrange(key) %>%
    select(-key) %>%
    as.matrix() -> WM

rownames(WM) <- keys$key

write_rds(WM, str_c(fp, 'PROCESSED_DATA/WM.RDS'))

# %%
us_mobility %>%
    inner_join(keys) %>%
    inner_join(policy) %>%
    inner_join(weather, by = c('key', 'date' = 'DATE')) %>%
    arrange(date, key) -> df
# Out:
# Joining, by = "key"
#
# Joining, by = c("key", "date")

# %%
df %>%
    select(-mhdt,
           -mnhdt,
           -mdtfh, 
           -device_count) -> df

# %%
weightedAlters <- function(df, wm, ...) {
    df %>% 
        select(date, key, ...) %>%
        spread(key = key, value = ...) %>%
        ungroup() %>%
        select(-date) %>%
        as.matrix() -> txn_data
    
    df %>%
        ungroup() %>%
        select(date) %>%
        distinct() %>%
        arrange(date) -> dates
    
    outMatrix <- tcrossprod(txn_data, wm)
    colnames(outMatrix) <- colnames(txn_data)
    
    data.frame(dates, outMatrix) %>%
        gather(key = 'key', value = 'value', -date) %>%
        arrange(date, key) %>%
        select(-date, -key) -> out_df
    return(out_df$value)
}

# %%
nquantiles <- 10

df %>%
    ungroup() %>%
    select(date, key, PRCP, TMAX) %>%
    mutate(PRCP = ifelse(PRCP == 0, NA, PRCP),
           pq = ifelse(is.na(PRCP), 0, ntile(PRCP, nquantiles)), 
           tq = ntile(TMAX, nquantiles)) -> weather_quantiles

wq_ind <- function(thres) {
    weather_quantiles %>%
        transmute(tempname1 = as.numeric(pq >= thres),
                  tempname2 = as.numeric(tq >= thres)) -> temp
    colnames(temp) <- c(str_c('prcp', str_pad(thres, 2, pad = '0')), str_c('tmax', str_pad(thres, 2, pad = '0'))) 
    return(temp)
}

wq_inds <- foreach(i = 1:nquantiles, .combine = cbind) %dopar% wq_ind(i)
wq_colnames <- c(str_c('prcp', str_pad(1:nquantiles, 2, pad = '0')), str_c('tmax', str_pad(1:nquantiles, 2, pad = '0')))

df %>%
    bind_cols(wq_inds[wq_colnames] %>% select(-tmax01)) -> df

# %%
colnames(df)
# Out:
#  [1] "key"       "date"      "pchd"      "mcbgv"     "plt1hafh"  "ppthgt75"
#  [7] "plt2kmt"   "n"         "cluster"   "reopening" "sdPolicy"  "stayHome"
# [13] "PRCP"      "TMAX"      "prcp01"    "prcp02"    "prcp03"    "prcp04"
# [19] "prcp05"    "prcp06"    "prcp07"    "prcp08"    "prcp09"    "prcp10"
# [25] "tmax02"    "tmax03"    "tmax04"    "tmax05"    "tmax06"    "tmax07"
# [31] "tmax08"    "tmax09"    "tmax10"

# %%
df %>%
    mutate_at(vars(pchd, mcbgv, plt1hafh, ppthgt75, plt2kmt, contains('prcp'), contains('tmax')), 
              .funs = list(sdp = function(x) x * df$sdPolicy,
                           shp = function(x) x * df$stayHome,
                           rop = function(x) x * df$reopening)) -> df
                           
df %>%
    select(-date, -key, -n, -cluster, -PRCP, -TMAX) %>%
    colnames() -> cols_to_alterize

alters <- foreach(i = 1:length(cols_to_alterize), .combine = cbind) %dopar% 
    weightedAlters(df, WM, cols_to_alterize[i])

colnames(alters) <- str_c('alter_', cols_to_alterize)

# %%
df %>%
    bind_cols(as.data.frame(alters)) %>%
    mutate_at(vars(matches('alter')), 
              .funs = list(Xego_sdp = function(x) x * df$sdPolicy,
                           Xego_shp = function(x) x * df$stayHome,
                           Xego_rop = function(x) x * df$reopening)) -> df

# %%
write_rds(df, str_c(fp, 'PROCESSED_DATA/panel_pre_xgr.RDS'))

# %%
policyPeriods <- read_csv(str_c(fp, 'PROCESSED_DATA/policyPeriods.csv'))
# Out:
# Parsed with column specification:
# cols(
#   cluster = col_character(),
#   name = col_character(),
#   sdPolicy = col_date(format = ""),
#   stayHome = col_date(format = ""),
#   reopening = col_date(format = "")
# )

# %%
library(ggplot2)
population %>%
    inner_join(keys) %>%
    ggplot(aes(x = log(n, 10))) + 
    geom_histogram(binwidth = 1, center = 0)
# Out:
# Joining, by = "key"
# plot without title

# %%
fit <- felm(plt1hafh ~ sdPolicy + stayHome + reopening + alter_sdPolicy + alter_stayHome + alter_reopening + 
            prcp01 + prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 + prcp09 + prcp10 +
                     tmax02 + tmax03 + tmax04 + tmax05 + tmax06 + tmax07 + tmax08 + tmax09 + tmax10
            | key + date
            | (alter_plt1hafh ~ 
               alter_prcp01 + alter_prcp02 + alter_prcp03 + alter_prcp04 + alter_prcp05 + 
               alter_prcp06 + alter_prcp07 + alter_prcp08 + alter_prcp09 + alter_prcp10 +
                              alter_tmax02 + alter_tmax03 + alter_tmax04 + alter_tmax05 + 
               alter_tmax06 + alter_tmax07 + alter_tmax08 + alter_tmax09 + alter_tmax10) 
            | cluster, df, weights = df$n)
summary(fit)
# Out:
# Call:
#    felm(formula = plt1hafh ~ sdPolicy + stayHome + reopening + alter_sdPolicy +      alter_stayHome + alter_reopening + prcp01 + prcp02 + prcp03 +      prcp04 + prcp05 + prcp06 + prcp07 + prcp08 + prcp09 + prcp10 +      tmax02 + tmax03 + tmax04 + tmax05 + tmax06 + tmax07 + tmax08 +      tmax09 + tmax10 | key + date | (alter_plt1hafh ~ alter_prcp01 +      alter_prcp02 + alter_prcp03 + alter_prcp04 + alter_prcp05 +      alter_prcp06 + alter_prcp07 + alter_prcp08 + alter_prcp09 +      alter_prcp10 + alter_tmax02 + alter_tmax03 + alter_tmax04 +      alter_tmax05 + alter_tmax06 + alter_tmax07 + alter_tmax08 +      alter_tmax09 + alter_tmax10) | cluster, data = df, weights = df$n)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -138.638   -2.345   -0.132    2.197  101.292
#
# Coefficients:
#                         Estimate Cluster s.e. t value Pr(>|t|)
# sdPolicy               5.744e-03    2.675e-03   2.147  0.03663 *
# ...

# %%
fit <- felm(plt1hafh ~ sdPolicy + stayHome + reopening + alter_sdPolicy + alter_stayHome + alter_reopening + 
            prcp01 + prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 + prcp09 + prcp10 +
                     tmax02 + tmax03 + tmax04 + tmax05 + tmax06 + tmax07 + tmax08 + tmax09 + tmax10
            | key + date
            | 0
            | cluster, df, weights = df$n)
summary(fit)
# Out:
# Call:
#    felm(formula = plt1hafh ~ (sdPolicy + stayHome + reopening) +      (alter_sdPolicy + alter_stayHome + alter_reopening) + prcp01 +      prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 +      prcp09 + prcp10 + tmax02 + tmax03 + tmax04 + tmax05 + tmax06 +      tmax07 + tmax08 + tmax09 + tmax10 | key + date | 0 | cluster,      data = df, weights = df$n)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -155.425   -3.662   -0.535    3.201  120.029
#
# Coefficients:
#                   Estimate Cluster s.e. t value Pr(>|t|)
# sdPolicy         0.0136790    0.0042119   3.248 0.002081 **
# stayHome         0.0147517    0.0061814   2.386 0.020837 *
# reopening        0.0314970    0.0086348   3.648 0.000631 ***
# alter_sdPolicy  -0.0318372    0.0083541  -3.811 0.000380 ***
# alter_stayHome  -0.0193202    0.0131204  -1.473 0.147143
# alter_reopening -0.0875602    0.0224222  -3.905 0.000283 ***
# ...

# %%
df %>%
    mutate(nquant = ntile(n, 2)) -> df

# %%
fit <- felm(plt1hafh ~ (sdPolicy + stayHome + reopening + alter_sdPolicy + alter_stayHome + alter_reopening) * as.factor(nquant) + 
            prcp01 + prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 + prcp09 + prcp10 +
                     tmax02 + tmax03 + tmax04 + tmax05 + tmax06 + tmax07 + tmax08 + tmax09 + tmax10
            | key + date
            | 0
            | cluster, df, weights = df$n)
summary(fit)
# Out:
# Call:
#    felm(formula = plt1hafh ~ (sdPolicy + stayHome + reopening +      alter_sdPolicy + alter_stayHome + alter_reopening) * as.factor(nquant) +      prcp01 + prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 +      prcp08 + prcp09 + prcp10 + tmax02 + tmax03 + tmax04 + tmax05 +      tmax06 + tmax07 + tmax08 + tmax09 + tmax10 | key + date |      0 | cluster, data = df, weights = df$n)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -152.087   -3.310   -0.311    2.837  118.962
#
# Coefficients:
#                                      Estimate Cluster s.e. t value Pr(>|t|)
# sdPolicy                            0.0710904    0.0121409   5.855 3.67e-07 ***
# stayHome                            0.0898806    0.0156879   5.729 5.75e-07 ***
# reopening                           0.1089141    0.0208660   5.220 3.47e-06 ***
# alter_sdPolicy                     -0.1394335    0.0187193  -7.449 1.19e-09 ***
# ...

# %%
df
# Out:
#        key   date       pchd      mcbgv    plt1hafh  ppthgt75  plt2kmt   n
# 1      01001 2020-03-01 0.2362245 2.467857 0.3719388 0.6098639 0.3722789  55601
# 2      01003 2020-03-01 0.2636410 2.147470 0.4210818 0.5916195 0.4124164 218022
# 3      01005 2020-03-01 0.2741062 2.132719 0.4187432 0.5585049 0.4512459  24881
# 4      01007 2020-03-01 0.2444347 2.368398 0.3753819 0.6062855 0.3937145  22400
# 5      01009 2020-03-01 0.2280778 2.455575 0.3490128 0.5963995 0.3864692  57840
# 6      01011 2020-03-01 0.3032368 2.027257 0.4446337 0.5349233 0.4718910  10138
# 7      01013 2020-03-01 0.2472058 2.168968 0.3944773 0.5950033 0.4385273  19680
# 8      01015 2020-03-01 0.2490972 2.370370 0.3881750 0.5715126 0.4186613 114277
# 9      01017 2020-03-01 0.2450479 2.424920 0.3712460 0.5476038 0.3955272  33615
# 10     01019 2020-03-01 0.2395714 2.297359 0.3800230 0.5598928 0.4041332  26032
# 11     01021 2020-03-01 0.2133144 2.425817 0.3428050 0.5735742 0.3718287  44153
# ...

# %%
fit <- felm(plt1hafh ~ (sdPolicy + stayHome + reopening) * as.factor(nquant) - as.factor(nquant) + 
            prcp01 + prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 + prcp09 + prcp10 +
                     tmax02 + tmax03 + tmax04 + tmax05 + tmax06 + tmax07 + tmax08 + tmax09 + tmax10
            | key + date
            | 0
            | cluster, df, weights = df$n)
summary(fit)
# Out:
# Call:
#    felm(formula = plt1hafh ~ (sdPolicy + stayHome + reopening) *      as.factor(nquant) - as.factor(nquant) + prcp01 + prcp02 +      prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 + prcp09 +      prcp10 + tmax02 + tmax03 + tmax04 + tmax05 + tmax06 + tmax07 +      tmax08 + tmax09 + tmax10 | key + date | 0 | cluster, data = df,      weights = df$n)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -153.798   -3.373   -0.314    2.883  119.013
#
# Coefficients:
#                                Estimate Cluster s.e. t value Pr(>|t|)
# sdPolicy                     -0.0515956    0.0060902  -8.472 3.13e-11 ***
# stayHome                     -0.0567066    0.0073945  -7.669 5.43e-10 ***
# reopening                    -0.0701743    0.0087353  -8.033 1.48e-10 ***
# prcp01                        0.0010499    0.0009486   1.107  0.27371
# prcp02                        0.0019846    0.0006600   3.007  0.00412 **
# ...

# %%
fit <- felm(pchd ~ (sdPolicy + alter_sdPolicy) + (stayHome + reopening) + (alter_stayHome + alter_reopening) +
            prcp01 + prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 + prcp09 + prcp10 +
                     tmax02 + tmax03 + tmax04 + tmax05 + tmax06 + tmax07 + tmax08 + tmax09 + tmax10
            | key + date
            | 0
            | cluster, temp, weights = temp$n)
summary(fit)
# Out:
# Call:
#    felm(formula = pchd ~ (sdPolicy + alter_sdPolicy) + (stayHome +      reopening) + (alter_stayHome + alter_reopening) + prcp01 +      prcp02 + prcp03 + prcp04 + prcp05 + prcp06 + prcp07 + prcp08 +      prcp09 + prcp10 + tmax02 + tmax03 + tmax04 + tmax05 + tmax06 +      tmax07 + tmax08 + tmax09 + tmax10 | key + date | 0 | cluster,      data = temp, weights = temp$n)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -184.619   -4.402   -0.792    3.938  122.730
#
# Coefficients:
#                   Estimate Cluster s.e. t value Pr(>|t|)
# sdPolicy         0.0165984    0.0056175   2.955 0.004762 **
# alter_sdPolicy  -0.0434191    0.0118814  -3.654 0.000618 ***
# stayHome         0.0169539    0.0084171   2.014 0.049381 *
# reopening        0.0301956    0.0078457   3.849 0.000338 ***
# alter_stayHome  -0.0151213    0.0153640  -0.984 0.329756
# alter_reopening -0.0763562    0.0214810  -3.555 0.000838 ***
# ...

# %%
df %>% 
    filter(n > 10000) %>%
    mutate(wk = week(date),
           doW = wday(date)) -> temp

# %%
df
# Out:
#        key   date       pchd      mcbgv    plt1hafh  ppthgt75  plt2kmt   n
# 1      01001 2020-03-01 0.2362245 2.467857 0.3719388 0.6098639 0.3722789  55601
# 2      01003 2020-03-01 0.2636410 2.147470 0.4210818 0.5916195 0.4124164 218022
# 3      01005 2020-03-01 0.2741062 2.132719 0.4187432 0.5585049 0.4512459  24881
# 4      01007 2020-03-01 0.2444347 2.368398 0.3753819 0.6062855 0.3937145  22400
# 5      01009 2020-03-01 0.2280778 2.455575 0.3490128 0.5963995 0.3864692  57840
# 6      01011 2020-03-01 0.3032368 2.027257 0.4446337 0.5349233 0.4718910  10138
# 7      01013 2020-03-01 0.2472058 2.168968 0.3944773 0.5950033 0.4385273  19680
# 8      01015 2020-03-01 0.2490972 2.370370 0.3881750 0.5715126 0.4186613 114277
# 9      01017 2020-03-01 0.2450479 2.424920 0.3712460 0.5476038 0.3955272  33615
# 10     01019 2020-03-01 0.2395714 2.297359 0.3800230 0.5598928 0.4041332  26032
# 11     01021 2020-03-01 0.2133144 2.425817 0.3428050 0.5735742 0.3718287  44153
# ...
