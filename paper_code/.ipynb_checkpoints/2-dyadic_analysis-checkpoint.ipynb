# %%
library(dplyr)
library(tidyr)
library(lfe)
library(stringr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack

# %%
df <- data.table::fread('/pool001/mfzhao/PROCESSED_DATA/dyadic_mvmt_2020.csv')

# %%
df %>% 
    filter(origin_cluster != destination_cluster) %>%
    mutate(oRain  = as.numeric(oPRCP > 0),
           dRain  = as.numeric(dPRCP > 0),
           nearby = as.numeric(dist < 100)) -> df

# %%
df %>%
    select(dyad, dist) %>%
    distinct()%>%
    ggplot(aes(x = dist)) +
    geom_histogram(binwidth = 0.2, center = 0.1) +
    scale_x_log10()
# Out:
# plot without title

# %%
df %>%
    select(-matches('op[123]:dp[123]')) %>%
    mutate(op1 = ifelse(op2 == 1 | op3 == 1, 0, op1),
           op2 = ifelse(op3 == 1, 0, op2)) -> df.op_mex

df %>%
    select(-matches('op[123]:dp[123]')) %>%
    mutate(dp1 = ifelse(dp2 == 1 | dp3 == 1, 0, dp1),
           dp2 = ifelse(dp3 == 1, 0, dp2)) -> df.dp_mex

# %%
fit1 <- felm(log(pdotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX, 2) + op1 + op2 + op3 + dp1 + dp2 + dp3
             | dyad + date | 0 | origin_cluster + destination_cluster, df)
fit2 <- felm(log(ndotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX, 2) + op1 + op2 + op3 + dp1 + dp2 + dp3
             | dyad + date | 0 | origin_cluster + destination_cluster, df)

# %%
df %>%
    select(-matches('op[123]:dp[123]')) %>%
    mutate_at(vars(matches('[od]p[123]')), 
              .funs = list(c  = function(x) x * .$nearby, 
                           nc = function(x) x * (1 - .$nearby))) -> df2

# %%
fit3 <- felm(log(pdotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX, 2) +
                          op1_c  + op2_c  + op3_c  + dp1_c  + dp2_c  + dp3_c + 
                          op1_nc + op2_nc + op3_nc + dp1_nc + dp2_nc + dp3_nc
             | dyad + date | 0 | origin_cluster + destination_cluster, df2)
fit4 <- felm(log(ndotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX, 2) +
                          op1_c  + op2_c  + op3_c  + dp1_c  + dp2_c  + dp3_c + 
                          op1_nc + op2_nc + op3_nc + dp1_nc + dp2_nc + dp3_nc
             | dyad + date | 0 | origin_cluster + destination_cluster, df2)

# %%
as.data.frame(summary(fit3)$coef) %>%
     mutate(var  = rownames(.),
            dv   = 'pdotd', 
            type = ifelse(str_detect(var, '_nc'), 'not nearby', 'nearby'),
            var  = str_replace(var, '_n?c', '')) %>%
    bind_rows(as.data.frame(summary(fit4)$coef) %>% 
              mutate(var  = rownames(.),
                     dv   = 'ndotd', 
                     type = ifelse(str_detect(var, '_nc'), 'not nearby', 'nearby'),
                     var  = str_replace(var, '_n?c', ''))) %>%
    rename(estimate = Estimate, se = `Cluster s.e.`) %>%
    bind_rows(as.data.frame(summary(fit1)$coef) %>%
              mutate(var = rownames(.),
                     dv = 'pdotd') %>%
              bind_rows(as.data.frame(summary(fit2)$coef) %>%
                        mutate(var = rownames(.),
                               dv = 'ndotd')) %>%
              rename(estimate = Estimate, se = `Cluster s.e.`) %>%
              mutate(type = 'all')) %>%
    filter(!str_detect(var, 'Rain'), !str_detect(var, 'TMAX')) -> temp

# %%
options(repr.plot.width=15, repr.plot.height=10)
ggplot(temp, aes(x = var, y = estimate, color = type)) + 
    geom_hline(aes(yintercept = 0), linetype = 2) +
    geom_point(position = position_dodge(0.5), size = 3) +
    geom_linerange(aes(ymin = estimate - 1.98 * se, ymax = estimate + 1.98 * se), 
                   position = position_dodge(0.5), size = 1) +
    xlab('') + 
    ylab('') +
    facet_grid(dv ~ .) +
    theme_light() +
    theme(text = element_text(size=20),
          legend.position = 'bottom')
# Out:
# plot without title

# %%
df.op_mex %>%
    mutate(o   = ifelse(op3 == 1, 'p3', 
                     ifelse(op2 == 1, 'p2', 
                        ifelse(op1 == 1, 'p1', 'p0'))),
           dp0 = 1) -> df.op_mex

bind_rows(as.data.frame(model.matrix(ndotd ~ 0 + o * (dp0 + dp1 + dp2 + dp3), df.op_mex)))

# %%
df.op_mex %>%
    select(date, dyad, origin_cluster, destination_cluster, n, nearby, bordering, dist, 
           ndotd, pdotd, oRain, dRain, oTMAX, dTMAX) %>%
    bind_columns(as.data.frame(model.matrix(ndotd ~ 0 + o * (dp0 + dp1 + dp2 + dp3), df.op_mex))) -> df.opex
# Out:
# Error in bind_columns(., as.data.frame(model.matrix(ndotd ~ 0 + o * (dp0 + : could not find function "bind_columns"
# Traceback:
#
# 1. df.op_mex %>% select(date, dyad, origin_cluster, destination_cluster,
#  .     n, nearby, bordering, dist, ndotd, pdotd, oRain, dRain, oTMAX,
#  .     dTMAX) %>% bind_columns(as.data.frame(model.matrix(ndotd ~
#  .     0 + o * (dp0 + dp1 + dp2 + dp3), df.op_mex)))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
as.data.frame(model.matrix(ndotd ~ 0 + o * (dp0 + dp1 + dp2 + dp3), df.op_mex)
# Out:
#         date       dyad         origin_cluster destination_cluster n
# 1       2020-01-01 01001->13121 1              13                   55601
# 2       2020-01-01 01003->04013 1               4                  218022
# 3       2020-01-01 01003->12005 1              12                  218022
# 4       2020-01-01 01003->12031 1              12                  218022
# 5       2020-01-01 01003->12033 1              12                  218022
# 6       2020-01-01 01003->12073 1              12                  218022
# 7       2020-01-01 01003->12091 1              12                  218022
# 8       2020-01-01 01003->12095 1              12                  218022
# 9       2020-01-01 01003->12113 1              12                  218022
# 10      2020-01-01 01003->12131 1              12                  218022
# 11      2020-01-01 01003->13121 1              13                  218022
# 12      2020-01-01 01003->17031 1              17                  218022
# 13      2020-01-01 01003->22019 1              22                  218022
# 14      2020-01-01 01003->22033 1              22                  218022
# 15      2020-01-01 01003->22051 1              22                  218022
# 16      2020-01-01 01003->22057 1              22                  218022
# 17      2020-01-01 01003->22063 1              22                  218022
# 18      2020-01-01 01003->22071 1              22                  218022
# 19      2020-01-01 01003->22103 1              22                  218022
# 20      2020-01-01 01003->22105 1              22                  218022
# 21      2020-01-01 01003->28035 1              28                  218022
# 22      2020-01-01 01003->28039 1              28                  218022
# 23      2020-01-01 01003->28045 1              28                  218022
# 24      2020-01-01 01003->28047 1              28                  218022
# 25      2020-01-01 01003->28059 1              28                  218022
# 26      2020-01-01 01003->28073 1              28                  218022
# 27      2020-01-01 01003->28075 1              28                  218022
# 28      2020-01-01 01003->28087 1              28                  218022
# 29      2020-01-01 01003->28121 1              28                  218022
# 30      2020-01-01 01003->47037 1              47                  218022
# ⋮       ⋮          ⋮            ⋮              ⋮                   ⋮
# 6214907 <NA>       NA           NA             NA                  NA
# 6214908 <NA>       NA           NA             NA                  NA
# 6214909 <NA>       NA           NA             NA                  NA
# 6214910 <NA>       NA           NA             NA                  NA
# 6214911 <NA>       NA           NA             NA                  NA
# 6214912 <NA>       NA           NA             NA                  NA
# 6214913 <NA>       NA           NA             NA                  NA
# 6214914 <NA>       NA           NA             NA                  NA
# 6214915 <NA>       NA           NA             NA                  NA
# 6214916 <NA>       NA           NA             NA                  NA
# 6214917 <NA>       NA           NA             NA                  NA
# 6214918 <NA>       NA           NA             NA                  NA
# 6214919 <NA>       NA           NA             NA                  NA
# 6214920 <NA>       NA           NA             NA                  NA
# 6214921 <NA>       NA           NA             NA                  NA
# 6214922 <NA>       NA           NA             NA                  NA
# 6214923 <NA>       NA           NA             NA                  NA
# 6214924 <NA>       NA           NA             NA                  NA
# 6214925 <NA>       NA           NA             NA                  NA
# 6214926 <NA>       NA           NA             NA                  NA
# 6214927 <NA>       NA           NA             NA                  NA
# 6214928 <NA>       NA           NA             NA                  NA
# 6214929 <NA>       NA           NA             NA                  NA
# 6214930 <NA>       NA           NA             NA                  NA
# 6214931 <NA>       NA           NA             NA                  NA
# 6214932 <NA>       NA           NA             NA                  NA
# 6214933 <NA>       NA           NA             NA                  NA
# 6214934 <NA>       NA           NA             NA                  NA
# 6214935 <NA>       NA           NA             NA                  NA
# 6214936 <NA>       NA           NA             NA                  NA
#         nearby bordering dist       ndotd pdotd        ⋯ op3:dp0 op1:dp1
# 1       0      0          246.28540  88   1.599709e-02 ⋯ NA      NA
# 2       0      0         2351.89961  26   1.252348e-03 ⋯ NA      NA
# 3       0      0          208.17543  24   1.156014e-03 ⋯ NA      NA
# 4       0      0          582.48358  11   5.298396e-04 ⋯ NA      NA
# 5       1      1           34.00226 998   4.807090e-02 ⋯ NA      NA
# 6       0      0          331.98103  15   7.225085e-04 ⋯ NA      NA
# 7       0      0          108.30828  83   3.997881e-03 ⋯ NA      NA
# 8       0      0          666.99306 179   8.621935e-03 ⋯ NA      NA
# 9       1      0           66.94946 107   5.153894e-03 ⋯ NA      NA
# 10      0      0          149.09305  87   4.190550e-03 ⋯ NA      NA
# 11      0      0          457.74477 103   4.961225e-03 ⋯ NA      NA
# 12      0      0         1233.06236  20   9.633447e-04 ⋯ NA      NA
# 13      0      0          543.51111   2   9.633447e-05 ⋯ NA      NA
# 14      0      0          324.07007  19   9.151775e-04 ⋯ NA      NA
# 15      0      0          254.71226  60   2.890034e-03 ⋯ NA      NA
# 16      0      0          291.35736   8   3.853379e-04 ⋯ NA      NA
# 17      0      0          290.08293   7   3.371707e-04 ⋯ NA      NA
# 18      0      0          224.08025 133   6.406242e-03 ⋯ NA      NA
# 19      0      0          217.19695  59   2.841867e-03 ⋯ NA      NA
# 20      0      0          257.42037  12   5.780068e-04 ⋯ NA      NA
# 21      0      0          155.35153  15   7.225085e-04 ⋯ NA      NA
# 22      1      0           89.45491  11   5.298396e-04 ⋯ NA      NA
# 23      0      0          172.88503   9   4.335051e-04 ⋯ NA      NA
# 24      0      0          136.55570 195   9.392611e-03 ⋯ NA      NA
# 25      1      0           90.60068  51   2.456529e-03 ⋯ NA      NA
# 26      0      0          178.54110  10   4.816724e-04 ⋯ NA      NA
# 27      0      0          206.00316  14   6.743413e-04 ⋯ NA      NA
# 28      0      0          311.79455  12   5.780068e-04 ⋯ NA      NA
# 29      0      0          271.23510  17   8.188430e-04 ⋯ NA      NA
# 30      0      0          609.65565  63   3.034536e-03 ⋯ NA      NA
# ⋮       ⋮      ⋮         ⋮          ⋮     ⋮            ⋱ ⋮       ⋮
# 6214907 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214908 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214909 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214910 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214911 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214912 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214913 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214914 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214915 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214916 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214917 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214918 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214919 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214920 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214921 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214922 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214923 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214924 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214925 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214926 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214927 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214928 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214929 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214930 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214931 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214932 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214933 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214934 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214935 NA     NA        NA         NA    NA           ⋯ 1       0
# 6214936 NA     NA        NA         NA    NA           ⋯ 1       0
#         op2:dp1 op3:dp1 op1:dp2 op2:dp2 op3:dp2 op1:dp3 op2:dp3 op3:dp3
# 1       NA      NA      NA      NA      NA      NA      NA      NA
# 2       NA      NA      NA      NA      NA      NA      NA      NA
# 3       NA      NA      NA      NA      NA      NA      NA      NA
# 4       NA      NA      NA      NA      NA      NA      NA      NA
# 5       NA      NA      NA      NA      NA      NA      NA      NA
# 6       NA      NA      NA      NA      NA      NA      NA      NA
# 7       NA      NA      NA      NA      NA      NA      NA      NA
# 8       NA      NA      NA      NA      NA      NA      NA      NA
# 9       NA      NA      NA      NA      NA      NA      NA      NA
# 10      NA      NA      NA      NA      NA      NA      NA      NA
# 11      NA      NA      NA      NA      NA      NA      NA      NA
# 12      NA      NA      NA      NA      NA      NA      NA      NA
# 13      NA      NA      NA      NA      NA      NA      NA      NA
# 14      NA      NA      NA      NA      NA      NA      NA      NA
# 15      NA      NA      NA      NA      NA      NA      NA      NA
# 16      NA      NA      NA      NA      NA      NA      NA      NA
# 17      NA      NA      NA      NA      NA      NA      NA      NA
# 18      NA      NA      NA      NA      NA      NA      NA      NA
# 19      NA      NA      NA      NA      NA      NA      NA      NA
# 20      NA      NA      NA      NA      NA      NA      NA      NA
# 21      NA      NA      NA      NA      NA      NA      NA      NA
# 22      NA      NA      NA      NA      NA      NA      NA      NA
# 23      NA      NA      NA      NA      NA      NA      NA      NA
# 24      NA      NA      NA      NA      NA      NA      NA      NA
# 25      NA      NA      NA      NA      NA      NA      NA      NA
# 26      NA      NA      NA      NA      NA      NA      NA      NA
# 27      NA      NA      NA      NA      NA      NA      NA      NA
# 28      NA      NA      NA      NA      NA      NA      NA      NA
# 29      NA      NA      NA      NA      NA      NA      NA      NA
# 30      NA      NA      NA      NA      NA      NA      NA      NA
# ⋮       ⋮       ⋮       ⋮       ⋮       ⋮       ⋮       ⋮       ⋮
# 6214907 0       1       0       0       1       0       0       1
# 6214908 0       1       0       0       1       0       0       1
# 6214909 0       1       0       0       1       0       0       1
# 6214910 0       1       0       0       1       0       0       1
# 6214911 0       1       0       0       1       0       0       1
# 6214912 0       1       0       0       0       0       0       1
# 6214913 0       1       0       0       0       0       0       1
# 6214914 0       1       0       0       0       0       0       1
# 6214915 0       1       0       0       0       0       0       1
# 6214916 0       1       0       0       0       0       0       1
# 6214917 0       1       0       0       1       0       0       1
# 6214918 0       1       0       0       1       0       0       1
# 6214919 0       1       0       0       1       0       0       1
# 6214920 0       1       0       0       1       0       0       1
# 6214921 0       1       0       0       1       0       0       1
# 6214922 0       1       0       0       1       0       0       1
# 6214923 0       1       0       0       1       0       0       1
# 6214924 0       1       0       0       1       0       0       1
# 6214925 0       1       0       0       1       0       0       1
# 6214926 0       1       0       0       1       0       0       1
# 6214927 0       1       0       0       1       0       0       1
# 6214928 0       1       0       0       1       0       0       1
# 6214929 0       1       0       0       1       0       0       1
# 6214930 0       1       0       0       0       0       0       1
# 6214931 0       1       0       0       0       0       0       1
# 6214932 0       1       0       0       1       0       0       1
# 6214933 0       1       0       0       0       0       0       1
# 6214934 0       1       0       0       0       0       0       1
# 6214935 0       1       0       0       0       0       0       1
# 6214936 0       1       0       0       0       0       0       1

# %%
df.opex %>%
    mutate(`op0:dp0` = op0 * dp0,
           `op0:dp1` = op0 * dp1,
           `op0:dp2` = op0 * dp2,
           `op0:dp3` = op0 * dp3) -> df.opex

colnames(df.opex) <- str_replace(colnames(df.opex), ':', '_')

# %%
df.opex
# Out:
#         date       dyad         origin_cluster destination_cluster n
# 1       2020-01-01 01001->13121 1              13                   55601
# 2       2020-01-01 01003->04013 1               4                  218022
# 3       2020-01-01 01003->12005 1              12                  218022
# 4       2020-01-01 01003->12031 1              12                  218022
# 5       2020-01-01 01003->12033 1              12                  218022
# 6       2020-01-01 01003->12073 1              12                  218022
# 7       2020-01-01 01003->12091 1              12                  218022
# 8       2020-01-01 01003->12095 1              12                  218022
# 9       2020-01-01 01003->12113 1              12                  218022
# 10      2020-01-01 01003->12131 1              12                  218022
# 11      2020-01-01 01003->13121 1              13                  218022
# 12      2020-01-01 01003->17031 1              17                  218022
# 13      2020-01-01 01003->22019 1              22                  218022
# 14      2020-01-01 01003->22033 1              22                  218022
# 15      2020-01-01 01003->22051 1              22                  218022
# 16      2020-01-01 01003->22057 1              22                  218022
# 17      2020-01-01 01003->22063 1              22                  218022
# 18      2020-01-01 01003->22071 1              22                  218022
# 19      2020-01-01 01003->22103 1              22                  218022
# 20      2020-01-01 01003->22105 1              22                  218022
# 21      2020-01-01 01003->28035 1              28                  218022
# 22      2020-01-01 01003->28039 1              28                  218022
# 23      2020-01-01 01003->28045 1              28                  218022
# 24      2020-01-01 01003->28047 1              28                  218022
# 25      2020-01-01 01003->28059 1              28                  218022
# 26      2020-01-01 01003->28073 1              28                  218022
# 27      2020-01-01 01003->28075 1              28                  218022
# 28      2020-01-01 01003->28087 1              28                  218022
# 29      2020-01-01 01003->28121 1              28                  218022
# 30      2020-01-01 01003->47037 1              47                  218022
# ⋮       ⋮          ⋮            ⋮              ⋮                   ⋮
# 6214907 <NA>       NA           NA             NA                  NA
# 6214908 <NA>       NA           NA             NA                  NA
# 6214909 <NA>       NA           NA             NA                  NA
# 6214910 <NA>       NA           NA             NA                  NA
# 6214911 <NA>       NA           NA             NA                  NA
# 6214912 <NA>       NA           NA             NA                  NA
# 6214913 <NA>       NA           NA             NA                  NA
# 6214914 <NA>       NA           NA             NA                  NA
# 6214915 <NA>       NA           NA             NA                  NA
# 6214916 <NA>       NA           NA             NA                  NA
# 6214917 <NA>       NA           NA             NA                  NA
# 6214918 <NA>       NA           NA             NA                  NA
# 6214919 <NA>       NA           NA             NA                  NA
# 6214920 <NA>       NA           NA             NA                  NA
# 6214921 <NA>       NA           NA             NA                  NA
# 6214922 <NA>       NA           NA             NA                  NA
# 6214923 <NA>       NA           NA             NA                  NA
# 6214924 <NA>       NA           NA             NA                  NA
# 6214925 <NA>       NA           NA             NA                  NA
# 6214926 <NA>       NA           NA             NA                  NA
# 6214927 <NA>       NA           NA             NA                  NA
# 6214928 <NA>       NA           NA             NA                  NA
# 6214929 <NA>       NA           NA             NA                  NA
# 6214930 <NA>       NA           NA             NA                  NA
# 6214931 <NA>       NA           NA             NA                  NA
# 6214932 <NA>       NA           NA             NA                  NA
# 6214933 <NA>       NA           NA             NA                  NA
# 6214934 <NA>       NA           NA             NA                  NA
# 6214935 <NA>       NA           NA             NA                  NA
# 6214936 <NA>       NA           NA             NA                  NA
#         nearby bordering dist       ndotd pdotd        ⋯ op1_dp2 op2_dp2
# 1       0      0          246.28540  88   1.599709e-02 ⋯ NA      NA
# 2       0      0         2351.89961  26   1.252348e-03 ⋯ NA      NA
# 3       0      0          208.17543  24   1.156014e-03 ⋯ NA      NA
# 4       0      0          582.48358  11   5.298396e-04 ⋯ NA      NA
# 5       1      1           34.00226 998   4.807090e-02 ⋯ NA      NA
# 6       0      0          331.98103  15   7.225085e-04 ⋯ NA      NA
# 7       0      0          108.30828  83   3.997881e-03 ⋯ NA      NA
# 8       0      0          666.99306 179   8.621935e-03 ⋯ NA      NA
# 9       1      0           66.94946 107   5.153894e-03 ⋯ NA      NA
# 10      0      0          149.09305  87   4.190550e-03 ⋯ NA      NA
# 11      0      0          457.74477 103   4.961225e-03 ⋯ NA      NA
# 12      0      0         1233.06236  20   9.633447e-04 ⋯ NA      NA
# 13      0      0          543.51111   2   9.633447e-05 ⋯ NA      NA
# 14      0      0          324.07007  19   9.151775e-04 ⋯ NA      NA
# 15      0      0          254.71226  60   2.890034e-03 ⋯ NA      NA
# 16      0      0          291.35736   8   3.853379e-04 ⋯ NA      NA
# 17      0      0          290.08293   7   3.371707e-04 ⋯ NA      NA
# 18      0      0          224.08025 133   6.406242e-03 ⋯ NA      NA
# 19      0      0          217.19695  59   2.841867e-03 ⋯ NA      NA
# 20      0      0          257.42037  12   5.780068e-04 ⋯ NA      NA
# 21      0      0          155.35153  15   7.225085e-04 ⋯ NA      NA
# 22      1      0           89.45491  11   5.298396e-04 ⋯ NA      NA
# 23      0      0          172.88503   9   4.335051e-04 ⋯ NA      NA
# 24      0      0          136.55570 195   9.392611e-03 ⋯ NA      NA
# 25      1      0           90.60068  51   2.456529e-03 ⋯ NA      NA
# 26      0      0          178.54110  10   4.816724e-04 ⋯ NA      NA
# 27      0      0          206.00316  14   6.743413e-04 ⋯ NA      NA
# 28      0      0          311.79455  12   5.780068e-04 ⋯ NA      NA
# 29      0      0          271.23510  17   8.188430e-04 ⋯ NA      NA
# 30      0      0          609.65565  63   3.034536e-03 ⋯ NA      NA
# ⋮       ⋮      ⋮         ⋮          ⋮     ⋮            ⋱ ⋮       ⋮
# 6214907 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214908 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214909 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214910 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214911 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214912 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214913 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214914 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214915 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214916 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214917 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214918 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214919 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214920 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214921 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214922 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214923 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214924 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214925 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214926 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214927 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214928 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214929 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214930 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214931 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214932 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214933 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214934 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214935 NA     NA        NA         NA    NA           ⋯ 0       0
# 6214936 NA     NA        NA         NA    NA           ⋯ 0       0
#         op3_dp2 op1_dp3 op2_dp3 op3_dp3 op0_dp0 op0_dp1 op0_dp2 op0_dp3
# 1       NA      NA      NA      NA      NA      NA      NA      NA
# 2       NA      NA      NA      NA      NA      NA      NA      NA
# 3       NA      NA      NA      NA      NA      NA      NA      NA
# 4       NA      NA      NA      NA      NA      NA      NA      NA
# 5       NA      NA      NA      NA      NA      NA      NA      NA
# 6       NA      NA      NA      NA      NA      NA      NA      NA
# 7       NA      NA      NA      NA      NA      NA      NA      NA
# 8       NA      NA      NA      NA      NA      NA      NA      NA
# 9       NA      NA      NA      NA      NA      NA      NA      NA
# 10      NA      NA      NA      NA      NA      NA      NA      NA
# 11      NA      NA      NA      NA      NA      NA      NA      NA
# 12      NA      NA      NA      NA      NA      NA      NA      NA
# 13      NA      NA      NA      NA      NA      NA      NA      NA
# 14      NA      NA      NA      NA      NA      NA      NA      NA
# 15      NA      NA      NA      NA      NA      NA      NA      NA
# 16      NA      NA      NA      NA      NA      NA      NA      NA
# 17      NA      NA      NA      NA      NA      NA      NA      NA
# 18      NA      NA      NA      NA      NA      NA      NA      NA
# 19      NA      NA      NA      NA      NA      NA      NA      NA
# 20      NA      NA      NA      NA      NA      NA      NA      NA
# 21      NA      NA      NA      NA      NA      NA      NA      NA
# 22      NA      NA      NA      NA      NA      NA      NA      NA
# 23      NA      NA      NA      NA      NA      NA      NA      NA
# 24      NA      NA      NA      NA      NA      NA      NA      NA
# 25      NA      NA      NA      NA      NA      NA      NA      NA
# 26      NA      NA      NA      NA      NA      NA      NA      NA
# 27      NA      NA      NA      NA      NA      NA      NA      NA
# 28      NA      NA      NA      NA      NA      NA      NA      NA
# 29      NA      NA      NA      NA      NA      NA      NA      NA
# 30      NA      NA      NA      NA      NA      NA      NA      NA
# ⋮       ⋮       ⋮       ⋮       ⋮       ⋮       ⋮       ⋮       ⋮
# 6214907 1       0       0       1       0       0       0       0
# 6214908 1       0       0       1       0       0       0       0
# 6214909 1       0       0       1       0       0       0       0
# 6214910 1       0       0       1       0       0       0       0
# 6214911 1       0       0       1       0       0       0       0
# 6214912 0       0       0       1       0       0       0       0
# 6214913 0       0       0       1       0       0       0       0
# 6214914 0       0       0       1       0       0       0       0
# 6214915 0       0       0       1       0       0       0       0
# 6214916 0       0       0       1       0       0       0       0
# 6214917 1       0       0       1       0       0       0       0
# 6214918 1       0       0       1       0       0       0       0
# 6214919 1       0       0       1       0       0       0       0
# 6214920 1       0       0       1       0       0       0       0
# 6214921 1       0       0       1       0       0       0       0
# 6214922 1       0       0       1       0       0       0       0
# 6214923 1       0       0       1       0       0       0       0
# 6214924 1       0       0       1       0       0       0       0
# 6214925 1       0       0       1       0       0       0       0
# 6214926 1       0       0       1       0       0       0       0
# 6214927 1       0       0       1       0       0       0       0
# 6214928 1       0       0       1       0       0       0       0
# 6214929 1       0       0       1       0       0       0       0
# 6214930 0       0       0       1       0       0       0       0
# 6214931 0       0       0       1       0       0       0       0
# 6214932 1       0       0       1       0       0       0       0
# 6214933 0       0       0       1       0       0       0       0
# 6214934 0       0       0       1       0       0       0       0
# 6214935 0       0       0       1       0       0       0       0
# 6214936 0       0       0       1       0       0       0       0

# %%
fit7 <- felm(log(ndotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX, 2) + 
                          op0_dp0 + op0_dp1 + op0_dp2 + op0_dp3 +
                          op1_dp0 + op1_dp1 + op1_dp2 + op1_dp3 +
                          op2_dp0 + op2_dp1 + op2_dp2 + op2_dp3 +
                          op3_dp0 + op3_dp1 + op3_dp2 + op3_dp3 
             | dyad + date | 0 | origin_cluster + destination_cluster, df.opex)
# Out:
# Error in poly(oTMAX, 2): missing values are not allowed in 'poly'
# Traceback:
#
# 1. felm(log(ndotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX,
#  .     2) + op0_dp0 + op0_dp1 + op0_dp2 + op0_dp3 + op1_dp0 + op1_dp1 +
#  .     op1_dp2 + op1_dp3 + op2_dp0 + op2_dp1 + op2_dp2 + op2_dp3 +
#  .     op3_dp0 + op3_dp1 + op3_dp2 + op3_dp3 | dyad + date | 0 |
#  .     origin_cluster + destination_cluster, df.opex)
# 2. makematrix(mf, contrasts, pf = parent.frame(), clustervar, wildcard = wildcard)
# 3. eval(mfcall)
# 4. eval(mfcall)
# 5. evalq(model.frame(formula = log(ndotd) ~ oRain + dRain + poly(oTMAX,
#  .     2) + poly(dTMAX, 2) + op0_dp0 + op0_dp1 + op0_dp2 + op0_dp3 +
#  .     op1_dp0 + op1_dp1 + op1_dp2 + op1_dp3 + op2_dp0 + op2_dp1 +
#  .     op2_dp2 + op2_dp3 + op3_dp0 + op3_dp1 + op3_dp2 + op3_dp3 +
#  .     dyad + date + origin_cluster + destination_cluster - 1, data = ..pdata.coerce..(df.opex),
#  .     drop.unused.levels = TRUE), <environment>)
# 6. evalq(model.frame(formula = log(ndotd) ~ oRain + dRain + poly(oTMAX,
#  .     2) + poly(dTMAX, 2) + op0_dp0 + op0_dp1 + op0_dp2 + op0_dp3 +
#  .     op1_dp0 + op1_dp1 + op1_dp2 + op1_dp3 + op2_dp0 + op2_dp1 +
#  .     op2_dp2 + op2_dp3 + op3_dp0 + op3_dp1 + op3_dp2 + op3_dp3 +
#  .     dyad + date + origin_cluster + destination_cluster - 1, data = ..pdata.coerce..(df.opex),
#  .     drop.unused.levels = TRUE), <environment>)
# 7. model.frame(formula = log(ndotd) ~ oRain + dRain + poly(oTMAX,
#  .     2) + poly(dTMAX, 2) + op0_dp0 + op0_dp1 + op0_dp2 + op0_dp3 +
#  .     op1_dp0 + op1_dp1 + op1_dp2 + op1_dp3 + op2_dp0 + op2_dp1 +
#  .     op2_dp2 + op2_dp3 + op3_dp0 + op3_dp1 + op3_dp2 + op3_dp3 +
#  .     dyad + date + origin_cluster + destination_cluster - 1, data = ..pdata.coerce..(df.opex),
#  .     drop.unused.levels = TRUE)
# 8. model.frame.Formula(formula = log(ndotd) ~ oRain + dRain + poly(oTMAX,
#  .     2) + poly(dTMAX, 2) + op0_dp0 + op0_dp1 + op0_dp2 + op0_dp3 +
#  .     op1_dp0 + op1_dp1 + op1_dp2 + op1_dp3 + op2_dp0 + op2_dp1 +
#  .     op2_dp2 + op2_dp3 + op3_dp0 + op3_dp1 + op3_dp2 + op3_dp3 +
#  .     dyad + date + origin_cluster + destination_cluster - 1, data = ..pdata.coerce..(df.opex),
#  .     drop.unused.levels = TRUE)
# 9. model.frame(terms(formula, lhs = lhs, rhs = rhs, data = data,
#  .     dot = dot), data = data, ...)
# 10. model.frame.default(terms(formula, lhs = lhs, rhs = rhs, data = data,
#   .     dot = dot), data = data, ...)
# 11. eval(predvars, data, env)
# 12. eval(predvars, data, env)
# 13. poly(oTMAX, 2)
# 14. stop("missing values are not allowed in 'poly'")

# %%
summary(fit7)

# %%
as.data.frame(summary(fit3)$coef) %>%
     mutate(var = rownames(.),
            dv = 'pdotd') %>%
    rename(estimate = Estimate, se = `Cluster s.e.`) %>%
    bind_rows(as.data.frame(summary(fit2)$coef) %>%
              mutate(var = rownames(.),
                     dv = 'ndotd') %>%
              rename(estimate = Estimate, se = `Cluster s.e.`)) %>%
    filter(!str_detect(var, 'Rain'), !str_detect(var, 'TMAX')) -> temp

# %%
temp %>%
    ggplot(aes(x = var, y = estimate, color = type)) + 
    geom_hline(aes(yintercept = 0), linetype = 2) +
    geom_point(position = position_dodge(0.5), size = 2) +
    geom_linerange(aes(ymin = estimate - 1.98 * se, ymax = estimate + 1.98 * se), position = position_dodge(0.5), size = .5) +
    xlab('') + 
    ylab('') +
    labs(color = "type") +
    theme_light() +
    theme(text = element_text(size=20),
          legend.position = 'bottom')

# %%
as.data.frame(summary(fit1)$coef) %>%
    mutate(var = rownames(.),
           type = ifelse(str_detect(var, 'nb$'), 'not bordering', 'bordering'),
           var = str_replace(var, 'n?b', '')) %>%
    rename(estimate = Estimate, se = `Cluster s.e.`) %>%
    bind_rows(as.data.frame(summary(fit2)$coef) %>%
              mutate(var = rownames(.),
                     type = 'all') %>%
              rename(estimate = Estimate, se = `Cluster s.e.`)) %>%
    ggplot(aes(x = var, y = estimate, color = type)) + 
    geom_hline(aes(yintercept = 0), linetype = 2) +
    geom_point(position = position_dodge(0.5), size = 2) +
    geom_linerange(aes(ymin = estimate - 1.98 * se, ymax = estimate + 1.98 * se), position = position_dodge(0.5), size = .5) +
    xlab('') + 
    ylab('') +
    labs(color = "type") +
    theme_light() +
    theme(text = element_text(size=20),
          legend.position = 'bottom')

# %%
fit1 <- felm(log(ndotd) ~ (op1 + op2 + op3 + dp1 + dp2 + dp3)
             | dyad + date | 0 | origin_cluster + destination_cluster, brdr)
summary(fit1)

# %%
fit1 <- felm(log(pdotd) ~ oRain1 + oRain2 + poly(oTMAX, 2) + poly(dTMAX, 2) +
             op1 + op2 + op3 + dp1 + dp2 + dp3 + 
             op1:dp1 + op1:dp2 + op1:dp3 + 
             op2:dp1 + op2:dp2 + op2:dp3 + 
             op3:dp1 + op3:dp2 + op3:dp3
             | dyad + date | 0 | origin_cluster + destination_cluster, df, weights = df$n)
summary(fit1)

# %%
fit1 <- felm(log(ndotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX, 2) +
             op2 + op3 + dp2 + dp3 +
             op2:dp2 + op2:dp3 + 
             op3:dp2 + op3:dp3
             | dyad + date | 0 | origin_cluster + destination_cluster, df)
summary(fit1)

# %%
fit1 <- felm(log(pdotd) ~ oRain + dRain + poly(oTMAX, 2) + poly(dTMAX, 2) +
             op2 + op3 + dp2 + dp3 +
             op2:dp2 + op2:dp3 + 
             op3:dp2 + op3:dp3
             | dyad + date | 0 | origin_cluster + destination_cluster, df, weights = df$n)
summary(fit1)

# %%
df %>%
    mutate(op1 = ifelse(op2 == 1 | op3 == 1, 0, op1),
           op2 = ifelse(op3 == 1, 0, op2),
           dp1 = ifelse(dp2 == 1 | dp3 == 1, 0, dp1),
           dp2 = ifelse(dp3 == 1, 0, dp2)) %>%
    select(date, dyad, op1, op2, op3, dp1, dp2, dp3) %>%
    mutate(D_o = ifelse(op3 == 1, 'op3',
                        ifelse(op2 == 1, 'op2', 
                               ifelse(op1 == 1, 'op1', 'op0'))), 
           D_d = ifelse(dp3 == 1, 'dp3',
                        ifelse(dp2 == 1, 'dp2', 
                               ifelse(dp1 == 1, 'dp1', 'dp0')))) %>%
    group_by(D_o, D_d) %>%
    tally()
# Out:
#    D_o D_d n
# 1  op0 dp0 1262386
# 2  op0 dp1   25853
# 3  op0 dp2     754
# 4  op1 dp0   25956
# 5  op1 dp1  150782
# 6  op1 dp2   66973
# 7  op1 dp3    3699
# 8  op2 dp0     954
# 9  op2 dp1   70416
# 10 op2 dp2  529627
# 11 op2 dp3   90424
# 12 op3 dp1    3562
# 13 op3 dp2   83334
# 14 op3 dp3  792748

# %%
df %>%
    mutate(origin = str_sub(dyad, 1, 5)) %>%
    select(origin, n) %>%
    distinct() %>%
    arrange(n) %>%
    summarize(sum(n))
# Out:
#   sum(n)
# 1 298896648

# %%
93923802/298896648
# Out:
# [1] 0.314235
